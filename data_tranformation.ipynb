# %%
# Psssss READ ME! 👋👓
# Highlevel code structure: 
    # 1) Import of packages, data and DataTransformer class
    # 2) Execution of the transformation:
        # 3.1) Creation of an object from DataTransformer class
        # 3.2) Rename all columns
        # 3.3) Transform data per column
        # 3.4) Drop unnecessary columns
        # 3.5) Save transformed data into a .csv file. The preogram will ask for a name. Name suggested: "hr_data_transformed.csv" 
# Testing code:
    # For each step of the process the program prints the results of a 'quick_check' so that it can be reviewed to confirm that is working correctly

# %%
# Imports 📥

# Packages
#-----------------------------------------------------------------------
import pandas as pd
import numpy as np

# DataTransformer class
import sys                  # allows manipulation of the module search path
import os                   # to handle file paths more flexibly

sys.path.append(os.path.abspath('People-Analytics'))    # Adds the People-Analytics folder to the sys.path, which allows Python to find the data_transformer module.

from data_transformer.data_transformer import DataTransformer     # Import the DataTransformer class from the data_transformer.py file.
from datetime import datetime

# Settings
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # to see all columns in DataFrames


# Data 
# -----------------------------------------------------------------------
df = pd.read_csv("Exploratory_Data_Analysis/HR RAW DATA.csv", index_col=0)

# %%
# create outputfile name

today_date_time = datetime.now()

file_name = input("Please enter a name for the output file") + "_" + today_date_time.strftime("%Y-%m-%d_%H:%M:%S") + ".csv"

# %%
# print for testing

df.head()
# Out:
#   Age Attrition BusinessTravel DailyRate                Department  \
# 0  51        No            NaN    684,0$                       NaN
# 1  52        No            NaN    699,0$                       NaN
# 2  42        No  travel_rarely    532,0$   Research & Development
# 3  47        No  travel_rarely    359,0$                       NaN
# 4  46        No            NaN   1319,0$                       NaN
#
#    DistanceFromHome  Education    EducationField  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#   employeenumber  EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  \
# 0          162,0                        1       0         51               3
# 1          259,0                        3       0         65               2
# 2          319,0                        3       0         58               3
# 3            NaN                        1       1         82               3
# 4            NaN                        1       1         45               4
#
#    JobLevel              JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0         5   resEArch DIREcToR                 3           NaN       19537,0
# 1         5             ManAGeR                 3           NaN       19999,0
# 2         5             ManaGER                 4       Married       19232,0
# 3         4   ReseArCH DIrECtOr                 3       Married       17169,0
# 4         4     sAleS EXECUtIve                 1      Divorced           NaN
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
# 2         4933                   1    NaN       No                 11
# 3        26703                   3      Y      NaN                 19
# 4         7739                   2      Y       No                 12
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2           NaN                 2
# 4               3,0                         4           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
# 3                NaN                        5                     6
# 4                NaN                        2                     8
#
#   SameAsMonthlyIncome  DateBirth       Salary  \
# 0             19537,0       1972  1000000000$
# 1             19999,0       1971  1000000000$
# 2             19232,0       1981  1000000000$
# 3             17169,0       1976  1000000000$
# 4                 NaN       1977  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0

# %%
# ▶️ Instantiating a class object 🐣

abc_data = DataTransformer(df)

# print for testing
abc_data.df.head(2)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
# 1  52        No            NaN    699,0$        NaN                 1
#
#    Education EducationField  employeecount employeenumber  \
# 0          3            NaN              1          162,0
# 1          4  Life Sciences              1          259,0
#
#    EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1       0         51               3         5
# 1                        3       0         65               2         5
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
#
#   SameAsMonthlyIncome  DateBirth       Salary RoleDepartament  NUMBERCHILDREN  \
# 0             19537,0       1972  1000000000$             NaN             NaN
# 1             19999,0       1971  1000000000$             NaN             NaN
#
#   RemoteWork
# 0        Yes
# 1          1

# %%
# ▶️ Rename columns

abc_data.rename_columns()

# print for checking

abc_data.df.head(1)
# Out:
#   age attrition business_travel daily_rate department  distance_from_home  \
# 0  51        No             NaN     684,0$        NaN                   6
#
#    education education_field  employee_count employee_number  \
# 0          3             NaN               1           162,0
#
#    environment_satisfaction  gender hourly_rate  job_involvement  job_level  \
# 0                         1       0          51                3          5
#
#               job_role  job_satisfaction marital_status monthly_income  \
# 0   resEArch DIREcToR                  3            NaN        19537,0
#
#    monthly_rate  num_companies_worked over_18 over_time  percent_salary_hike  \
# 0          6462                     7       Y        No                   13
#
#   performance_rating  relationship_satisfaction standard_hours  \
# 0                3,0                          3            NaN
#
#    stock_option_level total_working_years  training_times_last_year  \
# 0                   0                 NaN                         5
#
#   work_life_balance  years_at_company years_in_current_role  \
# 0               3,0                20                   NaN
#
#    years_since_last_promotion  years_with_curr_manager same_as_monthly_income  \
# 0                          15                       15                19537,0
#
#    date_birth       salary role_departament  number_children remote_work
# 0        1972  1000000000$              NaN              NaN         Yes

# %%
# ▶️ Transform "age" column data

column_name = "age"
# convert number written in letters into into numbers written in numbers

abc_data.convert_age_to_numbers()

# convert column to "int"

abc_data.convert_to_numeric (column_name,"integer")

# print for testing

abc_data.quick_check(column_name)
# Out:
# /mnt/c/Users/carla/Desktop/Adalab/module_3/project/People-Analytics/data_transformer/data_transformer.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["age"][index] = conversion_dictionary[value]
# Value 'forty-seven' was transformed into '47'
# Value 'fifty-eight' was transformed into '58'
# Value 'thirty-six' was transformed into '36'
# Value 'fifty-five' was transformed into '55'
# Value 'fifty-two' was transformed into '52'
# Value 'thirty-one' was transformed into '31'
# Value 'thirty' was transformed into '30'
# Value 'twenty-six' was transformed into '26'
# Value 'thirty-seven' was transformed into '37'
# Value 'thirty-two' was transformed into '32'
# Value 'twenty-four' was transformed into '24'
# Value 'thirty-two' was transformed into '32'
# Column name: age
# Data type: int8
# Unique values: [51 52 42 47 46 48 59 41 56 38 55 40 58 35 45 33 36 34 53 43 60 32 37 49
#  39 50 44 30 29 31 54 57 27 28 26 25 24 23 22 21 20 19 18]
# Not null count: 1614
# Null count: 0
# Duplicated values: 1571

# %%
# ▶️ Transform "distance_from_home" column data

# Corrects negative values in the distance_from_home column

abc_data.fix_negative_distances()

# print for testing
print("Printing 'distance_from_home' colum unique values for testing:")
print(abc_data.df["distance_from_home"].unique())
# Out:
# Printing 'distance_from_home' colum unique values for testing:
# [ 6  1  4  2  3 22 25  9  7 23 10 12 14 13 15  8 42 28 37  5 16 35 26 24
#  29 17 21 18 30 27 20 31 39 11 19 33 34 46 36 45 47 32 41 49 48 38 43 40
#  44]

# %%
# ▶️ Transform "environment_satisfaction" column data

abc_data.correct_env_satisfaction_values()

# print for testing

abc_data.quick_check("environment_satisfaction")

acceptance_criteria = "Data type is float and there isn't any value different than 1,2,3 or 4"
print (f"\nAcceptance criteria: {acceptance_criteria}")
# Out:
# Column name: environment_satisfaction
# Data type: float64
# Unique values: [ 1.  3.  4.  2. nan]
# Not null count: 1514
# Null count: 100
# Duplicated values: 1609
#
# Acceptance criteria: Data type is float and there isn't any value different than 1,2,3 or 4

# %%
# ▶️ Transform "gender" column data

# Replace the values in the Gender column with 'Male' and 'Female'

abc_data.replace_gender_values()

# print for checking

abc_data.quick_check("gender")

acceptance_criteria = "Unique values are male or female"
print (f"\nAcceptance criteria: {acceptance_criteria}")
# Out:
# Column name: gender
# Data type: object
# Unique values: ['Male' 'Female']
# Not null count: 1614
# Null count: 0
# Duplicated values: 1612
#
# Acceptance criteria: Unique values are male or female

# %%
# ▶️ Transform "hourly_rate" column data

abc_data.correct_hourly_rate()


# print for testing
abc_data.quick_check("hourly_rate")

acceptance_criteria = ""
print (f"\nAcceptance criteria: {acceptance_criteria}")
# Out:
# Column name: hourly_rate
# Data type: float64
# Unique values: [ 51.  65.  58.  82.  45.  99.  91.  64.  55.  68.  49.  61.  79.  31.
#   69.  48.  80.  74.  98.  59.  33.  56.  66.  57.  53.  87.  81.  84.
#   32.  41.  92.  47.  nan  43.  86.  30.  42.  88.  96.  67.  62.  72.
#   78.  89.  52.  50.  90.  37.  94.  76.  60.  46.  83. 100.  40.  97.
#   54.  75.  39.  85.  63.  44.  93.  36.  35.  73.  71.  70.  38.  77.
#   95.  34.]
# Not null count: 1530
# Null count: 84
# Duplicated values: 1542
#
# Acceptance criteria:

# %%
# ▶️ Transform "monthly_income" column data

abc_data.transform_to_float("monthly_income")

# print for testing

abc_data.quick_check("monthly_income")

acceptance_criteria = "\n- Datatye is numeric."
print (f"\nAcceptance criteria: {acceptance_criteria}")
# Out:
# Column name
#   924.  134.  755.  253.  922. 1365.  306. 1271. 1404. 1391. 1464. 1330.
#   773.  902.  107.  504. 1358.  824.  594.  734.  766.  431. 1213. 1373.
#  1324. 1123.  391.  125. 1357.  626.  132.  871. 1031. 1145.  854. 1411.
#   252.  833. 1210. 1463.  812. 1162.  845. 1144.  156.  464. 1305.  983.
#   534. 1306. 1094.  558.  959.  782.  362.  268.  167. 1243.  720.  868.
#  1252.  781. 1272.  129. 1069.  289.  955.  660.  415.  309.  130.  862.
#  1098.  969.  373.  599.  968.  830. 1423.  516.  598.  104.  479.  474.
#   264. 1059.  563. 1259.  369.  543.  964.  176.  181.  211.  590.  305.
#   478. 1294. 1128.  726.  352. 1172.  605. 1337.  105.]
# Not null count: 1490
# Null count: 124
# Duplicated values: 765

# %%
# ▶️ Transform "remote work"
abc_data.map_column_remote_work()

abc_data.quick_check("remote_work")
# Out:
# Column name: remote_work
# Data type: object
# Unique values: ['True' '1' 'False' '0']
# Not null count: 1614
# Null count: 0
# Duplicated values: 1610

# %%
# ▶️ Convert_role_to_department and normalize job_role letters

abc_data.convert_role_to_department_normalize_job_role()

# prints for testing

print("\n")
abc_data.quick_check("job_role")

print("\n")
abc_data.quick_check("department")

abc_data.df[["job_role","department"]].sample(50)
# Out:
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# ...
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Human Resources' was transformed into 'Human Resources'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Research Scientist' was transformed into 'Research & Development'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Representative' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Healthcare Representative' was transformed into 'Research & Development'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Laboratory Technician' was transformed into 'Research & Development'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Sales Executive' was transformed into 'Sales'
# Value 'Manufacturing Director' was transformed into 'Research & Development'
#
#
# Column name: job_role
# Data type: object
# Unique values: ['Research Director' 'Manager' 'Sales Executive' 'Manufacturing Director'
#  'Research Scientist' 'Healthcare Representative' 'Laboratory Technician'
#  'Sales Representative' 'Human Resources']
# Not null count: 1614
# Null count: 0
# Duplicated values: 1605
#
#
# Column name: department
# Data type: object
# Unique values: ['Research & Development' nan 'Sales' 'Human Resources']
# Not null count: 1523
# Null count: 91
# Duplicated values: 1610
#                        job_role              department
# 1354                    Manager                     NaN
# 1388      Laboratory Technician  Research & Development
# 1056            Sales Executive                   Sales
# 1452         Research Scientist  Research & Development
# 1227      Laboratory Technician  Research & Development
# 528      Manufacturing Director  Research & Development
# 1322         Research Scientist  Research & Development
# 1015            Sales Executive                   Sales
# 700             Sales Executive                   Sales
# 137   Healthcare Representative  Research & Development
# 866   Healthcare Representative  Research & Development
# 168   Healthcare Representative  Research & Development
# 869        Sales Representative                   Sales
# 1091         Research Scientist  Research & Development
# 1196       Sales Representative                   Sales
# 962       Laboratory Technician  Research & Development
# 775             Sales Executive                   Sales
# 1440            Human Resources         Human Resources
# 172       Laboratory Technician  Research & Development
# 649          Research Scientist  Research & Development
# 341           Research Director  Research & Development
# 1327      Laboratory Technician  Research & Development
# 382             Sales Executive                   Sales
# 235   Healthcare Representative  Research & Development
# 1463     Manufacturing Director  Research & Development
# 1041            Sales Executive                   Sales
# 1509          Research Director  Research & Development
# 609                     Manager                   Sales
# 791             Sales Executive                   Sales
# 202       Laboratory Technician  Research & Development
# 139      Manufacturing Director  Research & Development
# 814           Research Director  Research & Development
# 1274            Sales Executive                   Sales
# 828             Sales Executive                   Sales
# 861      Manufacturing Director  Research & Development
# 1485         Research Scientist  Research & Development
# 411             Sales Executive                   Sales
# 577       Laboratory Technician  Research & Development
# 523             Sales Executive                   Sales
# 599             Sales Executive                   Sales
# 1531            Sales Executive                   Sales
# 1577            Sales Executive                   Sales
# 762   Healthcare Representative  Research & Development
# 1280            Sales Executive                   Sales
# 231           Research Director  Research & Development
# 1058      Laboratory Technician  Research & Development
# 192          Research Scientist  Research & Development
# 399             Sales Executive                   Sales
# 261           Research Director  Research & Development
# 1305      Laboratory Technician  Research & Development

# %%
# ▶️ Drop un-needed coulumns

columns_to_delete = ["employee_count", "same_as_monthly_income", "salary", "number_children", "standard_hours", "years_in_current_role", "over_18", "role_departament"]

abc_data.drop_redundant_columns(columns_to_delete)

# print for testing

for i in range(len(columns_to_delete)):
    try:
        print(abc_data.df[i])
    except: 
        print(f"Column '{columns_to_delete[i]}' deleted")
# Out:
# Column 'employee_count' deleted
# Column 'same_as_monthly_income' deleted
# Column 'salary' deleted
# Column 'number_children' deleted
# Column 'standard_hours' deleted
# Column 'years_in_current_role' deleted
# Column 'over_18' deleted
# Column 'role_departament' deleted

# %%
# ▶️ Transform "employee_number" data: remove duplicates and change format to float

# abc_data.remove_duplicates() # we decided not to delete any row for now. Instead, we'll manage nulls and analyse further first.

abc_data.transform_to_float("employee_number")

# print for testing

abc_data.quick_check("employee_number")
acceptance_criteria = "\n- There are no duplicates other than NaN\n- Datatype is numeric"
print (f"\nAcceptance criteria: {acceptance_criteria}")
# Out:
# Column name: employee_number
# Data type: float64
# Unique values: [ 162.  259.  319. ... 2012. 2023. 2040.]
# Not null count: 1183
# Null count: 431
# Duplicated values: 534
#
# Acceptance criteria:
# - There are no duplicates other than NaN
# - Datatype is numeric

# %%
# ▶️ Change nulls for unknown category in categorial variable

# if we want to change more than one column , put a list
columns_modify = []
abc_data.change_null_for_unknown(columns_modify)


# print for tasting

for column in columns_modify:
    abc_data.quick_check(column)
    print("--------------------------------")

# %%
# ▶️ Change nulls for mode in categorical variable

# if we want to change more than one column, put a list
columns_modify = []
abc_data.change_null_for_mode(columns_modify)


# print for tasting
for column in columns_modify:
    abc_data.quick_check(column)
    print("--------------------------------")

# %%
# ▶️ Change nulls for mean in numerical variable when we have a 0-10% of nulls in numerical category and distribution is normal

# if we want to change more than one column , put a list
columns_modify = []
abc_data.change_null_for_mean(columns_modify)

# print for tasting
for column in columns_modify:
    abc_data.quick_check(column)
    print("--------------------------------")

# %%
# ▶️ Change nulls for median in numerical variable when we have a 0-10% of nulls in numerical category and distribution is atypical

# if we want to change more than one column , put a list
columns_modify = []
abc_data.change_null_for_median(columns_modify)

# print for tasting
for column in columns_modify:
    abc_data.quick_check(column)
    print("--------------------------------")

# %%
# ▶️ Change nulls for distribution KNN in numerical variable when we have more 10% of nulls in numerical category 

# if we want to change more than one column , put a list
columns_modify = []
abc_data.change_null_for_mean(columns_modify)


# print for tasting
for column in columns_modify:
    abc_data.quick_check(column)
    print("--------------------------------")

# %%
# ▶️ create .csv

try:
    abc_data.create_csv(file_name)
    print (f"{file_name} created ✅ {abc_data.df.shape[0]} rows, {abc_data.df.shape[1]} columns.")
except:
    print("Error❌ 'file_name' is needed. Please assign a name for the final output with the transformed data to continue")
# Out:
# hr_data_transformed.csv created ✅ 1614 rows, 33 columns.
