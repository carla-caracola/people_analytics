# %%
# Libraries 
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
from auto_eda import AutoEDA

# Configuration
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_rows', None)

# %%
eda = AutoEDA()
df = eda.read_file('HR RAW DATA.csv')
eda.explo_df(df)
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1614 non-null   object
#  1   Attrition                 1614 non-null   object
#  2   BusinessTravel            842 non-null    object
#  3   DailyRate                 1614 non-null   object
#  4   Department                302 non-null    object
#  5   DistanceFromHome          1614 non-null   int64
#  6   Education                 1614 non-null   int64
#  7   EducationField            869 non-null    object
#  8   employeecount             1614 non-null   int64
#  9   employeenumber            1183 non-null   object
#  10  EnvironmentSatisfaction   1614 non-null   int64
#  11  Gender                    1614 non-null   int64
#  12  HourlyRate                1614 non-null   object
#  13  JobInvolvement            1614 non-null   int64
#  14  JobLevel                  1614 non-null   int64
#  15  JobRole                   1614 non-null   object
#  16  JobSatisfaction           1614 non-null   int64
#  17  MaritalStatus             963 non-null    object
#  18  MonthlyIncome             771 non-null    object
#  19  MonthlyRate               1614 non-null   int64
#  20  NUMCOMPANIESWORKED        1614 non-null   int64
#  21  Over18                    713 non-null    object
#  22  OverTime                  938 non-null    object
#  23  PercentSalaryHike         1614 non-null   int64
#  24  PerformanceRating         1419 non-null   object
#  25  RelationshipSatisfaction  1614 non-null   int64
#  26  StandardHours             419 non-null    object
#  27  StockOptionLevel          1614 non-null   int64
#  28  TOTALWORKINGYEARS         1088 non-null   object
#  29  TrainingTimesLastYear     1614 non-null   int64
#  30  WORKLIFEBALANCE           1506 non-null   object
#  31  YearsAtCompany            1614 non-null   int64
#  32  YearsInCurrentRole        34 non-null     object
#  33  YearsSinceLastPromotion   1614 non-null   int64
#  34  YEARSWITHCURRMANAGER      1614 non-null   int64
#  35  SameAsMonthlyIncome       771 non-null    object
#  36  DateBirth                 1614 non-null   int64
#  37  Salary                    1614 non-null   object
#  38  RoleDepartament           302 non-null    object
#  39  NUMBERCHILDREN            0 non-null      float64
#  40  RemoteWork                1614 non-null   object
# dtypes: float64(1), int64(18), object(22)
# memory usage: 529.6+ KB
# None
# First 10 rows of the DataFrame:
#   Age Attrition     BusinessTravel DailyRate                Department  \
# 0  51        No                NaN    684,0$                       NaN
# 1  52        No                NaN    699,0$                       NaN
# 2  42        No      travel_rarely    532,0$   Research & Development
# 3  47        No      travel_rarely    359,0$                       NaN
# 4  46        No                NaN   1319,0$                       NaN
# 5  48        No                NaN    117,0$   Research & Development
# 6  59        No                NaN   1435,0$                       NaN
# 7  42        No      travel_rarely    635,0$                       NaN
# 8  41        No                NaN   1276,0$                       NaN
# 9  41        No  travel_frequently    840,0$                       NaN
#
#    DistanceFromHome  Education    EducationField  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
# 5                22          3           Medical              1
# 6                25          3     Life Sciences              1
# 7                 1          1               NaN              1
# 8                 2          5               NaN              1
# 9                 9          3               NaN              1
#
#   employeenumber  EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  \
# 0          162,0                        1       0         51               3
# 1          259,0                        3       0         65               2
# 2          319,0                        3       0         58               3
# 3            NaN                        1       1         82               3
# 4            NaN                        1       1         45               4
# 5         1900,0                        4       1         58               3
# 6           81,0                        1       1         99               3
# 7          387,0                        2       0         99               3
# 8            NaN                        2       1         91               3
# 9          999,0                        1       0         64               3
#
#    JobLevel              JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0         5   resEArch DIREcToR                 3           NaN       19537,0
# 1         5             ManAGeR                 3           NaN       19999,0
# 2         5             ManaGER                 4       Married       19232,0
# 3         4   ReseArCH DIrECtOr                 3       Married       17169,0
# 4         4     sAleS EXECUtIve                 1      Divorced           NaN
# 5         4             MANAger                 4           NaN       17174,0
# 6         3     Sales ExeCutIVe                 1           NaN           NaN
# 7         2     Sales eXEcUTiVe                 3       Married           NaN
# 8         4             mANAGEr                 1       Married       16595,0
# 9         5   reSEaRCH DIrectoR                 3           NaN           NaN
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
# 2         4933                   1    NaN       No                 11
# 3        26703                   3      Y      NaN                 19
# 4         7739                   2      Y       No                 12
# 5         2437                   3    NaN       No                 11
# 6         2354                   7      Y      NaN                 11
# 7        24532                   1    NaN       No                 25
# 8         5626                   7    NaN       No                 16
# 9         3735                   2    NaN       No                 17
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
# 2               3,0                         4           NaN                 0
# 3               3,0                         2           NaN                 2
# 4               3,0                         4           NaN                 1
# 5               3,0                         2           NaN                 1
# 6               3,0                         4           NaN                 0
# 7               4,0                         3           NaN                 0
# 8               3,0                         2           NaN                 1
# 9               3,0                         2           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
# 2              22,0                      3             NaN              22
# 3               NaN                      2             NaN              20
# 4               NaN                      5             3,0              19
# 5               NaN                      3             3,0              22
# 6              28,0                      3             2,0              21
# 7              20,0                      3             3,0              20
# 8              22,0                      2             3,0              18
# 9              21,0                      2             4,0              18
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
# 2                NaN                       11                    15
# 3                NaN                        5                     6
# 4                NaN                        2                     8
# 5                NaN                        4                     7
# 6                NaN                        7                     9
# 7                NaN                       11                     6
# 8                NaN                       11                     8
# 9                NaN                        0                    11
#
#   SameAsMonthlyIncome  DateBirth       Salary  \
# 0             19537,0       1972  1000000000$
# 1             19999,0       1971  1000000000$
# 2             19232,0       1981  1000000000$
# 3             17169,0       1976  1000000000$
# 4                 NaN       1977  1000000000$
# 5             17174,0       1975  1000000000$
# 6                 NaN       1964  1000000000$
# 7                 NaN       1981  1000000000$
# 8             16595,0       1982  1000000000$
# 9                 NaN       1982  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# 0                                   NaN             NaN        Yes
# 1                                   NaN             NaN          1
# 2   ManaGER  -  Research & Development              NaN          1
# 3                                   NaN             NaN      False
# 4                                   NaN             NaN          0
# 5   MANAger  -  Research & Development              NaN        Yes
# 6                                   NaN             NaN       True
# 7                                   NaN             NaN          0
# 8                                   NaN             NaN       True
# 9                                   NaN             NaN          0
# Last 10 rows of the DataFrame:
#      Age Attrition     BusinessTravel DailyRate                Department  \
# 1604  41       Yes                NaN   1085,0$   Research & Development
# 1605  31        No      travel_rarely    154,0$                       NaN
# 1606  26        No  travel_frequently   1283,0$                    Sales
# 1607  31        No                NaN    616,0$                       NaN
# 1608  32        No                NaN    498,0$                       NaN
# 1609  36       Yes      travel_rarely    530,0$                       NaN
# 1610  45        No         non-travel    805,0$                       NaN
# 1611  39        No      travel_rarely    903,0$                       NaN
# 1612  36        No         non-travel   1229,0$                       NaN
# 1613  46        No                NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 1604                 2          4     Life Sciences              1
# 1605                 7          4               NaN              1
# 1606                 1          3           Medical              1
# 1607                12          3           Medical              1
# 1608                 3          4           Medical              1
# 1609                 3          1     Life Sciences              1
# 1610                 4          2               NaN              1
# 1611               -13          5               NaN              1
# 1612                 8          4  Technical Degree              1
# 1613                 7          2           Medical              1
#
#      employeenumber  EnvironmentSatisfaction  Gender     HourlyRate  \
# 1604          927,0                        2       1  Not Available
# 1605          941,0                        2       0  Not Available
# 1606          956,0                        3       0             52
# 1607            NaN                        4       1             41
# 1608          966,0                        3       1             93
# 1609          967,0                        3       0             51
# 1610          972,0                        3       0             57
# 1611            NaN                       13       0             41
# 1612          990,0                        1       0             84
# 1613            NaN                        4       0             75
#
#       JobInvolvement  JobLevel                      JobRole  JobSatisfaction  \
# 1604               1         1       LAbORAToRy tEcHNICian                 4
# 1605               2         1        SAlES rEpreSENtaTiVe                 3
# 1606               2         2             sAleS EXECUtIvE                 1
# 1607               3         2   HEaltHCarE REPreSENtAtIve                 4
# 1608               3         2      MANUfaCtuRiNG DiReCtor                 1
# 1609               2         3             saLEs ExeCUTiVe                 4
# 1610               3         2       LAboRaTOry tECHNiCIAn                 2
# 1611               4         3             sAlES ExECUTivE                 3
# 1612               3         2             SaLes ExecUtIVe                 4
# 1613               3         3      mAnUfactURInG DiRECTOr                 3
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 1604      divorced           NaN        17725                   4    NaN
# 1605           NaN        2329,0        11737                   3    NaN
# 1606           NaN        4294,0        11148                   1      Y
# 1607           NaN           NaN        17369                   0    NaN
# 1608       Married        6725,0        13554                   1    NaN
# 1609       Married       10325,0         5518                   1      Y
# 1610           NaN        4447,0        23163                   1    NaN
# 1611        Single           NaN         2560                   0    NaN
# 1612      Divorced           NaN        25952                   4    NaN
# 1613           NaN       10845,0        24208                   6      Y
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 1604      Yes                 13               3,0                         3
# 1605      NaN                 15               NaN                         2
# 1606      NaN                 12               3,0                         2
# 1607      NaN                 11               3,0                         3
# 1608      NaN                 12               3,0                         3
# 1609      NaN                 11               NaN                         1
# 1610      NaN                 12               3,0                         2
# 1611       No                 18               3,0                         4
# 1612       No                 13               NaN                         4
# 1613      NaN                 13               3,0                         2
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 1604          80,0                 1               NaN                      1
# 1605          80,0                 0               NaN                      2
# 1606           NaN                 0               NaN                      2
# 1607           NaN                 2              10,0                      2
# 1608           NaN                 1               8,0                      2
# 1609           NaN                 1               NaN                      6
# 1610           NaN                 0               NaN                      5
# 1611           NaN                 0               9,0                      3
# 1612           NaN                 2              12,0                      3
# 1613           NaN                 1               NaN                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 1604             2,0               7                NaN
# 1605             4,0               7                NaN
# 1606             3,0               7                NaN
# 1607             1,0               9                NaN
# 1608             4,0               8                NaN
# 1609             3,0              16                NaN
# 1610             2,0               9                NaN
# 1611             3,0               8                NaN
# 1612             3,0               7                NaN
# 1613             3,0               8                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 1604                        1                     0                 NaN
# 1605                        5                     2              2329,0
# 1606                        0                     7              4294,0
# 1607                        8                     5                 NaN
# 1608                        6                     3              6725,0
# 1609                        3                     7             10325,0
# 1610                        0                     8              4447,0
# 1611                        0                     7                 NaN
# 1612                        0                     7                 NaN
# 1613                        0                     7             10845,0
#
#       DateBirth       Salary  \
# 1604       1982  1000000000$
# 1605       1992  1000000000$
# 1606       1997  1000000000$
# 1607       1992  1000000000$
# 1608       1991  1000000000$
# 1609       1987  1000000000$
# 1610       1978  1000000000$
# 1611       1984  1000000000$
# 1612       1987  1000000000$
# 1613       1977  1000000000$
#
#                                          RoleDepartament  NUMBERCHILDREN  \
# 1604   LAbORAToRy tEcHNICian  -  Research & Development              NaN
# 1605                                                 NaN             NaN
# 1606                          sAleS EXECUtIvE  -  Sales              NaN
# 1607                                                 NaN             NaN
# 1608                                                 NaN             NaN
# 1609                                                 NaN             NaN
# 1610                                                 NaN             NaN
# 1611                                                 NaN             NaN
# 1612                                                 NaN             NaN
# 1613                                                 NaN             NaN
#
#      RemoteWork
# 1604        Yes
# 1605       True
# 1606          1
# 1607       True
# 1608          1
# 1609          0
# 1610          1
# 1611        Yes
# 1612       True
# 1613          0
# Statistical description of the DataFrame (numeric):
#                            count          mean          std     min     25%  \
# DistanceFromHome          1614.0      4.527261    14.591913   -49.0     2.0
# Education                 1614.0      2.925031     1.022357     1.0     2.0
# employeecount             1614.0      1.000000     0.000000     1.0     1.0
# EnvironmentSatisfaction   1614.0      4.294919     6.993559     1.0     2.0
# Gender                    1614.0      0.398389     0.489718     0.0     0.0
# JobInvolvement            1614.0      2.739777     0.711567     1.0     2.0
# JobLevel                  1614.0      2.068154     1.101344     1.0     1.0
# JobSatisfaction           1614.0      2.738538     1.106163     1.0     2.0
# MonthlyRate               1614.0  14284.495663  7110.414585  2094.0  8001.0
# NUMCOMPANIESWORKED        1614.0      2.673482     2.506152     0.0     1.0
# PercentSalaryHike         1614.0     15.165428     3.648610    11.0    12.0
# RelationshipSatisfaction  1614.0      2.704461     1.079031     1.0     2.0
# StockOptionLevel          1614.0      0.791202     0.842396     0.0     0.0
# TrainingTimesLastYear     1614.0      2.809789     1.297765     0.0     2.0
# YearsAtCompany            1614.0      7.132590     6.124237     0.0     3.0
# YearsSinceLastPromotion   1614.0      2.245973     3.235665     0.0     0.0
# YEARSWITHCURRMANAGER      1614.0      4.220570     3.562695     0.0     2.0
# DateBirth                 1614.0   1986.076208     9.101332  1963.0  1980.0
# NUMBERCHILDREN               0.0           NaN          NaN     NaN     NaN
#
#                               50%      75%      max
# DistanceFromHome              5.0     11.0     29.0
# Education                     3.0      4.0      5.0
# employeecount                 1.0      1.0      1.0
# EnvironmentSatisfaction       3.0      4.0     49.0
# Gender                        0.0      1.0      1.0
# JobInvolvement                3.0      3.0      4.0
# JobLevel                      2.0      3.0      5.0
# JobSatisfaction               3.0      4.0      4.0
# MonthlyRate               14248.5  20364.0  26999.0
# NUMCOMPANIESWORKED            2.0      4.0      9.0
# PercentSalaryHike            14.0     18.0     25.0
# RelationshipSatisfaction      3.0      4.0      4.0
# StockOptionLevel              1.0      1.0      3.0
# TrainingTimesLastYear         3.0      3.0      6.0
# YearsAtCompany                5.0      9.0     40.0
# YearsSinceLastPromotion       1.0      3.0     15.0
# YEARSWITHCURRMANAGER          3.0      7.0     17.0
# DateBirth                  1987.0   1993.0   2005.0
# NUMBERCHILDREN                NaN      NaN      NaN
# Statistical description of the DataFrame (categorical):
#                     count unique                       top  freq
# Age                  1614     54                        35    84
# Attrition            1614      2                        No  1355
# BusinessTravel        842      3             travel_rarely   586
# DailyRate            1614    849                      nan$   124
# Department            302      3   Research & Development    196
# EducationField        869      6             Life Sciences   349
# employeenumber       1183   1079                     482,0     2
# HourlyRate           1614     72             Not Available    84
# JobRole              1614   1579                  mANager      4
# MaritalStatus         963      5                   Married   404
# MonthlyIncome         771    668                    6347,0     4
# Over18                713      1                         Y   713
# OverTime              938      2                        No   682
# PerformanceRating    1419      2                       3,0  1205
# StandardHours         419      1                      80,0   419
# TOTALWORKINGYEARS    1088     40                      10,0   144
# WORKLIFEBALANCE      1506      4                       3,0   913
# YearsInCurrentRole     34     10                       2,0    11
# SameAsMonthlyIncome   771    668                    6347,0     4
# Salary               1614      1               1000000000$  1614
# RoleDepartament       302    301        MaNAgeR  -  Sales      2
# RemoteWork           1614      5                         1   360
# Count of null values per column:
# Age                            0
# Attrition                      0
# BusinessTravel               772
# DailyRate                      0
# Department                  1312
# DistanceFromHome               0
# Education                      0
# EducationField               745
# employeecount                  0
# employeenumber               431
# EnvironmentSatisfaction        0
# Gender                         0
# HourlyRate                     0
# JobInvolvement                 0
# JobLevel                       0
# JobRole                        0
# JobSatisfaction                0
# MaritalStatus                651
# MonthlyIncome                843
# MonthlyRate                    0
# NUMCOMPANIESWORKED             0
# Over18                       901
# OverTime                     676
# PercentSalaryHike              0
# PerformanceRating            195
# RelationshipSatisfaction       0
# StandardHours               1195
# StockOptionLevel               0
# TOTALWORKINGYEARS            526
# TrainingTimesLastYear          0
# WORKLIFEBALANCE              108
# YearsAtCompany                 0
# YearsInCurrentRole          1580
# YearsSinceLastPromotion        0
# YEARSWITHCURRMANAGER           0
# SameAsMonthlyIncome          843
# DateBirth                      0
# Salary                         0
# RoleDepartament             1312
# NUMBERCHILDREN              1614
# RemoteWork                     0
# dtype: int64
# Percentage of null values per column (only columns with nulls):
# BusinessTravel          47.83
# Department              81.29
# EducationField          46.16
# employeenumber          26.70
# MaritalStatus           40.33
# MonthlyIncome           52.23
# Over18                  55.82
# OverTime                41.88
# PerformanceRating       12.08
# StandardHours           74.04
# TOTALWORKINGYEARS       32.59
# WORKLIFEBALANCE          6.69
# YearsInCurrentRole      97.89
# SameAsMonthlyIncome     52.23
# RoleDepartament         81.29
# NUMBERCHILDREN         100.00
# dtype: float64
# Rows with all values as null:
# There is no rows with all values as null.
#
# Count of duplicate rows:
# 0

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %%
eda.explo_df(df, 'RemoteWork')
# Out:
# Exploration of the column: RemoteWork
#
# Statistical description (categorical):
# count     1614
# unique       5
# top          1
# freq       360
# Name: RemoteWork, dtype: object
# Count of null values:
# 0
# Count of unique values:
# 5
# Unique values:
# array(['Yes', '1', 'False', '0', 'True'], dtype=object)
# Value Counts:
# RemoteWork
# 1        360
# True     345
# 0        309
# False    305
# Yes      295
# Name: count, dtype: int64
# Most frequent value (mode):
# '1'
# Count of duplicates in the column:
# 1609

# %%
df[['MonthlyRate', 'MonthlyIncome', 'HourlyRate', 'DailyRate']].reset_index()
# Out:
#       index  MonthlyRate MonthlyIncome HourlyRate DailyRate
# 0         0         6462       19537,0         51    684,0$
# 1         1         5678       19999,0         65    699,0$
# 2         2         4933       19232,0         58    532,0$
# 3         3        26703       17169,0         82    359,0$
# 4         4         7739           NaN         45   1319,0$
# ...     ...          ...           ...        ...       ...
# 1609   1609         5518       10325,0         51    530,0$
# 1610   1610        23163        4447,0         57    805,0$
# 1611   1611         2560           NaN         41    903,0$
# 1612   1612        25952           NaN         84   1229,0$
# 1613   1613        24208       10845,0         75    566,0$
#
# [1614 rows x 5 columns]

# %% [markdown]
# # NOTES / PREVIOUS CODES

# %%
def eda_summary(data):
    indexes = list(data.columns)
    cols = ['dtype', 'not_null_count', 'null_count', 'null_percent', 'duplicates', 'unique', 'top', 'freq', 'mean', 'std', 'min', 'max', '25%', '50%', '75%', 'description']

    data_eda = pd.DataFrame(index=indexes, columns=cols)

    descriptions = {
        'Age': 'La edad del empleado.',
        'Attrition': 'Indica si el empleado ha dejado la empresa ("No" significa que no ha dejado la empresa y "Yes" significa que ha dejado la empresa).',
        'BusinessTravel': 'Describe la frecuencia de los viajes relacionados con el trabajo del empleado (por ejemplo, "Travel_Rarely" para raramente).',
        'DailyRate': 'La tarifa diaria del empleado.',
        'Department': 'El departamento en el que trabaja el empleado (por ejemplo, "Research & Development", "Sales", etc.).',
        'DistanceFromHome': 'La distancia desde el hogar del empleado hasta su lugar de trabajo.',
        'Education': 'Nivel de educación del empleado (generalmente en una escala del 1 al 5).',
        'EducationField': 'El campo de educación del empleado.',
        'employeecount': 'Un contador que generalmente es 1 y se usa para contar empleados.',
        'employeenumber': 'Un número de identificación único para el empleado.',
        'EnvironmentSatisfaction': 'Nivel de satisfacción del empleado en relación con su entorno de trabajo. Con valores que estan comprendidos entre el 1 y el 4, siendo el 4 el nivel de máxima satisfacción.',
        'Gender': 'El género del empleado. Donde 0 corresponde con "hombre" y 1 con "mujer".',
        'HourlyRate': 'La tarifa por hora del empleado.',
        'JobInvolvement': 'Nivel de implicación del empleado en su trabajo.',
        'JobLevel': 'Nivel jerárquico del empleado en la empresa.',
        'JobRole': 'El rol o puesto de trabajo del empleado.',
        'JobSatisfaction': 'Nivel de satisfacción del empleado con su trabajo.',
        'MaritalStatus': 'El estado civil del empleado (por ejemplo, "Single", "Married", etc.).',
        'MonthlyIncome': 'Ingresos mensuales del empleado.',
        'MonthlyRate': 'Tasa mensual del empleado.',
        'NUMCOMPANIESWORKED': 'Número de compañías en las que el empleado ha trabajado.',
        'Over18': 'Indica si el empleado es mayor de 18 años.',
        'OverTime': 'Indica si el empleado trabaja horas extras ("Yes" para sí o "No" para no).',
        'PercentSalaryHike': 'El porcentaje de aumento salarial del empleado.',
        'PerformanceRating': 'Calificación de rendimiento del empleado.',
        'RelationshipSatisfaction': 'Nivel de satisfacción en las relaciones interpersonales del empleado.',
        'StandardHours': 'Las horas estándar de trabajo.',
        'StockOptionLevel': 'Nivel de opciones de compra de acciones del empleado.',
        'TOTALWORKINGYEARS': 'Total de años de experiencia laboral del empleado.',
        'TrainingTimesLastYear': 'Número de veces que el empleado recibió capacitación el año pasado.',
        'WORKLIFEBALANCE': 'Equilibrio entre trabajo y vida personal del empleado.',
        'YearsAtCompany': 'Años que el empleado ha trabajado en la empresa actual.',
        'YearsInCurrentRole': 'Años que el empleado ha estado en su puesto actual.',
        'YearsSinceLastPromotion': 'Años desde la última promoción del empleado.',
        'YEARSWITHCURRMANAGER': 'Años que el empleado ha estado bajo la supervisión del actual gerente.',
        'SameAsMonthlyIncome': 'Ingresos mensuales del empleado.',
        'DateBirth': 'Año de nacimiento del empleado (teniendo en cuenta que los datos fueron recogidos en el 2023).',
        'Salary': 'Salario de los empleados.',
        'RoleDepartament': 'El departamento y el rol del empleado.',
        'NUMBERCHILDREN': 'Número de hijos de los empleados.',
        'RemoteWork': 'Si el empleado puede teletrabajar o no.'
    }

    for var in indexes:
        data_eda.loc[var, 'dtype'] = data[var].dtype
        data_eda.loc[var, 'not_null_count'] = data[var].notnull().sum()
        data_eda.loc[var, 'null_count'] = data[var].isnull().sum()
        data_eda.loc[var, 'null_percent'] = str(round((data[var].isnull().sum() / len(data)) * 100, 2)) + '%'
        data_eda.loc[var, 'duplicates'] = data[var].duplicated().sum()
        data_eda.loc[var, 'unique'] = data[var].nunique() # if data[var].dtype == 'object' else None
        data_eda.loc[var, 'top'] = data[var].mode().iloc[0] if not data[var].mode().empty else None
        data_eda.loc[var, 'freq'] = data[var].value_counts().max() if not data[var].mode().empty else None
        data_eda.loc[var, 'mean'] = data[var].mean() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'std'] = data[var].std() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'min'] = data[var].min() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'max'] = data[var].max() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, '25%'] = data[var].quantile(0.25) if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, '50%'] = data[var].median() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, '75%'] = data[var].quantile(0.75) if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'description'] = descriptions.get(var, 'No description available')

    return data_eda

# %%
df_initial_eda = eda_summary(df)

# Description column left alignment
df_initial_eda['description'] = df_initial_eda['description'].apply(lambda x: f'{x:<}')

df_initial_eda = df_initial_eda.style.set_table_styles({
    'description': [{'selector': '', 'props': [('text-align', 'left')]}]
})

df_initial_eda = df_initial_eda.set_table_styles({
    'description': [{'selector': 'th', 'props': [('text-align', 'left')]}]
}, overwrite=False)

df_initial_eda

# %%
df.loc[df['employeenumber'].duplicated(keep=False), :].sort_values(by='employeenumber')

# %%
null_columns = df.isnull().sum()[df.isnull().sum() > 0]
null_percent = pd.DataFrame(null_columns, columns=['null_total_qty'])
null_percent['null_percent'] = (round((null_percent['null_total_qty'] / 1614) * 100, 2)).apply(lambda x: f"{x}%")
null_percent
# Out:
#                      null_total_qty null_percent
# BusinessTravel                  772       47.83%
# Department                     1312       81.29%
# EducationField                  745       46.16%
# employeenumber                  431        26.7%
# MaritalStatus                   651       40.33%
# MonthlyIncome                   843       52.23%
# Over18                          901       55.82%
# OverTime                        676       41.88%
# PerformanceRating               195       12.08%
# StandardHours                  1195       74.04%
# TOTALWORKINGYEARS               526       32.59%
# WORKLIFEBALANCE                 108        6.69%
# YearsInCurrentRole             1580       97.89%
# SameAsMonthlyIncome             843       52.23%
# RoleDepartament                1312       81.29%
# NUMBERCHILDREN                 1614       100.0%

# %% [markdown]
# # Eliminando duplicados de la columna employeenumber

# %%
duplicados = df.loc[df['employeenumber'].duplicated(keep=False), :].sort_values(by='employeenumber')
duplicados.shape # Nos llama la atención que haya 639 duplicados cuando el número de duplicados debería ser par.
# Out:
# (639, 41)

# %%
# Al verificar los nulos, comprobamos que el número ímpar se da por esa razón y subtraímos las filas nulas de las filas totales para saber cuantos duplicados hay.
# el resultado de la suma tiene que ser un número par.
duplicados.shape[0] - duplicados['employeenumber'].isnull().sum()
# Out:
# 208

# %%
# Concluímos que tenemos 208 empleados con el ID de empleado duplicado. 
# Ahora vamos a remover estos nulos de nuestro df de duplicados para poder tratar los duplicados. 
duplicados.dropna(subset='employeenumber', inplace=True)

# %%
# Verificamos como se quedó el df duplicados filtrado
duplicados.head(3)
# Out:
#      Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 987   33        No     non-travel   1038,0$     Sales                  8
# 1483  33        No     non-travel   1038,0$     Sales                  8
# 1484  26       Yes            NaN    342,0$        NaN                 2
#
#       Education EducationField  employeecount employeenumber  \
# 987           1  Life Sciences              1         1044,0
# 1483          1  Life Sciences              1         1044,0
# 1484          3  Life Sciences              1         1053,0
#
#       EnvironmentSatisfaction  Gender     HourlyRate  JobInvolvement  \
# 987                         2       1  Not Available               2
# 1483                        2       1             88               2
# 1484                        1       0             57               3
#
#       JobLevel                 JobRole  JobSatisfaction MaritalStatus  \
# 987          1   sALES ReprEsentatiVE                 4           NaN
# 1483         1   sales repResENTaTiVE                 4           NaN
# 1484         1     reSEArcH SCiEnTIst                 1       Married
#
#      MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  \
# 987            NaN        21437                   0      Y      NaN
# 1483           NaN        21437                   0      Y      NaN
# 1484        2042,0        15346                   6      Y      NaN
#
#       PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 987                  19               3,0                         4
# 1483                 19               3,0                         4
# 1484                 14               3,0                         2
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 987            NaN                 0               NaN                      2
# 1483           NaN                 0               NaN                      2
# 1484           NaN                 1               6,0                      2
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 987              2,0               2                NaN
# 1483             2,0               2                NaN
# 1484             3,0               3                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 987                         2                     2                 NaN
# 1483                        2                     2                 NaN
# 1484                        1                     2              2042,0
#
#       DateBirth       Salary                   RoleDepartament  \
# 987        1990  1000000000$   sALES ReprEsentatiVE  -  Sales
# 1483       1990  1000000000$   sales repResENTaTiVE  -  Sales
# 1484       1997  1000000000$                               NaN
#
#       NUMBERCHILDREN RemoteWork
# 987              NaN      False
# 1483             NaN          0
# 1484             NaN        Yes

# %%
# Ahora borramos todos los duplicados que tengan el menor indice, ya que suponemos que los de indice mayor son los registros mas actualizados. 
duplicados.index.name = 'index'  # Agregar nombre al índice
duplicados.head(2)
# Out:
#       Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# index
# 987    33        No     non-travel   1038,0$     Sales                  8
# 1483   33        No     non-travel   1038,0$     Sales                  8
#
#        Education EducationField  employeecount employeenumber  \
# index
# 987            1  Life Sciences              1         1044,0
# 1483           1  Life Sciences              1         1044,0
#
#        EnvironmentSatisfaction  Gender     HourlyRate  JobInvolvement  \
# index
# 987                          2       1  Not Available               2
# 1483                         2       1             88               2
#
#        JobLevel                 JobRole  JobSatisfaction MaritalStatus  \
# index
# 987           1   sALES ReprEsentatiVE                 4           NaN
# 1483          1   sales repResENTaTiVE                 4           NaN
#
#       MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  \
# index
# 987             NaN        21437                   0      Y      NaN
# 1483            NaN        21437                   0      Y      NaN
#
#        PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# index
# 987                   19               3,0                         4
# 1483                  19               3,0                         4
#
#       StandardHours  StockOptionLevel TOTALWORKINGYEARS  \
# index
# 987             NaN                 0               NaN
# 1483            NaN                 0               NaN
#
#        TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# index
# 987                        2             2,0               2
# 1483                       2             2,0               2
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# index
# 987                  NaN                        2                     2
# 1483                 NaN                        2                     2
#
#       SameAsMonthlyIncome  DateBirth       Salary  \
# index
# 987                   NaN       1990  1000000000$
# 1483                  NaN       1990  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# index
# 987     sALES ReprEsentatiVE  -  Sales              NaN      False
# 1483    sales repResENTaTiVE  -  Sales              NaN          0

# %%
# Ordenar el DataFrame por 'employeenumber' y por el índice en orden descendente
df_sorted = duplicados.sort_values(by=['employeenumber', duplicados.index.name], ascending=[True, False])
df_sorted
# Out:
#       Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# index
# 1483   33        No     non-travel   1038,0$     Sales                  8
# 987    33        No     non-travel   1038,0$     Sales                  8
# 1484   26       Yes            NaN    342,0$        NaN                 2
# 988    26       Yes            NaN    342,0$        NaN                 2
# 1486   46        No            NaN    430,0$        NaN                 1
# ...    ..       ...            ...       ...        ...               ...
# 366    36       Yes  travel_rarely    530,0$        NaN                 3
# 1610   45        No     non-travel    805,0$        NaN                 4
# 367    45        No     non-travel    805,0$        NaN               -47
# 1612   36        No     non-travel   1229,0$        NaN                 8
# 369    36        No     non-travel   1229,0$        NaN                 8
#
#        Education    EducationField  employeecount employeenumber  \
# index
# 1483           1     Life Sciences              1         1044,0
# 987            1     Life Sciences              1         1044,0
# 1484           3     Life Sciences              1         1053,0
# 988            3     Life Sciences              1         1053,0
# 1486           4           Medical              1         1069,0
# ...          ...               ...            ...            ...
# 366            1     Life Sciences              1          967,0
# 1610           2               NaN              1          972,0
# 367            2               NaN              1          972,0
# 1612           4  Technical Degree              1          990,0
# 369            4  Technical Degree              1          990,0
#
#        EnvironmentSatisfaction  Gender     HourlyRate  JobInvolvement  \
# index
# 1483                         2       1             88               2
# 987                          2       1  Not Available               2
# 1484                         1       0             57               3
# 988                          1       0             57               3
# 1486                         4       0             40               3
# ...                        ...     ...            ...             ...
# 366                          3       0             51               2
# 1610                         3       0             57               3
# 367                         47       0             57               3
# 1612                         1       0             84               3
# 369                          1       0             84               3
#
#        JobLevel                  JobRole  JobSatisfaction MaritalStatus  \
# index
# 1483          1    sales repResENTaTiVE                 4           NaN
# 987           1    sALES ReprEsentatiVE                 4           NaN
# 1484          1      reSEArcH SCiEnTIst                 1       Married
# 988           1      rEsEaRCH SCIenTiSt                 1       Married
# 1486          5       rESEArCh DIrecTOR                 4           NaN
# ...         ...                      ...              ...           ...
# 366           3         SALes EXECuTiVe                 4       Married
# 1610          2   LAboRaTOry tECHNiCIAn                 2           NaN
# 367           2   lABORaTory tecHNiCiAN                 2           NaN
# 1612          2         SaLes ExecUtIVe                 4      Divorced
# 369           2         SaLes EXeCuTiVE                 4      Divorced
#
#       MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  \
# index
# 1483            NaN        21437                   0      Y      NaN
# 987             NaN        21437                   0      Y      NaN
# 1484         2042,0        15346                   6      Y      NaN
# 988          2042,0        15346                   6      Y      NaN
# 1486            NaN        21445                   9    NaN       No
# ...             ...          ...                 ...    ...      ...
# 366         10325,0         5518                   1      Y      NaN
# 1610         4447,0        23163                   1    NaN      NaN
# 367          4447,0        23163                   1    NaN      NaN
# 1612            NaN        25952                   4    NaN       No
# 369             NaN        25952                   4    NaN       No
#
#        PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# index
# 1483                  19               3,0                         4
# 987                   19               3,0                         4
# 1484                  14               3,0                         2
# 988                   14               3,0                         2
# 1486                  17               3,0                         4
# ...                  ...               ...                       ...
# 366                   11               NaN                         1
# 1610                  12               3,0                         2
# 367                   12               3,0                         2
# 1612                  13               NaN                         4
# 369                   13               NaN                         4
#
#       StandardHours  StockOptionLevel TOTALWORKINGYEARS  \
# index
# 1483            NaN                 0               NaN
# 987             NaN                 0               NaN
# 1484            NaN                 1               6,0
# 988             NaN                 1               6,0
# 1486           80,0                 2              23,0
# ...             ...               ...               ...
# 366             NaN                 1               NaN
# 1610            NaN                 0               NaN
# 367             NaN                 0               NaN
# 1612            NaN                 2              12,0
# 369             NaN                 2              12,0
#
#        TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# index
# 1483                       2             2,0               2
# 987                        2             2,0               2
# 1484                       2             3,0               3
# 988                        2             3,0               3
# 1486                       0             3,0               2
# ...                      ...             ...             ...
# 366                        6             3,0              16
# 1610                       5             2,0               9
# 367                        5             2,0               9
# 1612                       3             3,0               7
# 369                        3             3,0               7
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# index
# 1483                 NaN                        2                     2
# 987                  NaN                        2                     2
# 1484                 NaN                        1                     2
# 988                  NaN                        1                     2
# 1486                 NaN                        2                     2
# ...                  ...                      ...                   ...
# 366                  NaN                        3                     7
# 1610                 NaN                        0                     8
# 367                  NaN                        0                     8
# 1612                 NaN                        0                     7
# 369                  NaN                        0                     7
#
#       SameAsMonthlyIncome  DateBirth       Salary  \
# index
# 1483                  NaN       1990  1000000000$
# 987                   NaN       1990  1000000000$
# 1484               2042,0       1997  1000000000$
# 988                2042,0       1997  1000000000$
# 1486                  NaN       1977  1000000000$
# ...                   ...        ...          ...
# 366               10325,0       1987  1000000000$
# 1610               4447,0       1978  1000000000$
# 367                4447,0       1978  1000000000$
# 1612                  NaN       1987  1000000000$
# 369                   NaN       1987  1000000000$
#
#                         RoleDepartament  NUMBERCHILDREN RemoteWork
# index
# 1483    sales repResENTaTiVE  -  Sales              NaN          0
# 987     sALES ReprEsentatiVE  -  Sales              NaN      False
# 1484                                NaN             NaN        Yes
# 988                                 NaN             NaN          1
# 1486                                NaN             NaN          1
# ...                                 ...             ...        ...
# 366                                 NaN             NaN          0
# 1610                                NaN             NaN          1
# 367                                 NaN             NaN          1
# 1612                                NaN             NaN       True
# 369                                 NaN             NaN        Yes
#
# [208 rows x 41 columns]

# %%
# Eliminar duplicados conservando el primer registro encontrado (índice más alto)
df_unique = df_sorted.drop_duplicates(subset='employeenumber', keep='first')
df_unique # nos hemos quedado con 104 filas
# Out:
#       Age Attrition     BusinessTravel DailyRate Department  DistanceFromHome  \
# index
# 1483   33        No         non-travel   1038,0$     Sales                  8
# 1484   26       Yes                NaN    342,0$        NaN                 2
# 1486   46        No                NaN    430,0$        NaN                 1
# 1487   21        No                NaN    984,0$        NaN               -25
# 1488   31        No  travel_frequently    793,0$        NaN                20
# ...    ..       ...                ...       ...        ...               ...
# 1606   26        No  travel_frequently   1283,0$     Sales                  1
# 1608   32        No                NaN    498,0$        NaN                 3
# 1609   36       Yes      travel_rarely    530,0$        NaN                 3
# 1610   45        No         non-travel    805,0$        NaN                 4
# 1612   36        No         non-travel   1229,0$        NaN                 8
#
#        Education    EducationField  employeecount employeenumber  \
# index
# 1483           1     Life Sciences              1         1044,0
# 1484           3     Life Sciences              1         1053,0
# 1486           4           Medical              1         1069,0
# 1487           1               NaN              1         1131,0
# 1488           3               NaN              1         1135,0
# ...          ...               ...            ...            ...
# 1606           3           Medical              1          956,0
# 1608           4           Medical              1          966,0
# 1609           1     Life Sciences              1          967,0
# 1610           2               NaN              1          972,0
# 1612           4  Technical Degree              1          990,0
#
#        EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# index
# 1483                         2       1         88               2         1
# 1484                         1       0         57               3         1
# 1486                         4       0         40               3         5
# 1487                         4       1         70               2         1
# 1488                         3       0         67               4         1
# ...                        ...     ...        ...             ...       ...
# 1606                         3       0         52               2         2
# 1608                         3       1         93               3         2
# 1609                         3       0         51               2         3
# 1610                         3       0         57               3         2
# 1612                         1       0         84               3         2
#
#                         JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# index
# 1483      sales repResENTaTiVE                 4           NaN           NaN
# 1484        reSEArcH SCiEnTIst                 1       Married        2042,0
# 1486         rESEArCh DIrecTOR                 4           NaN           NaN
# 1487        REsEaRch scIenTIsT                 2        Single        2070,0
# 1488      saLES RePRESenTAtIve                 4       Married        2791,0
# ...                         ...              ...           ...           ...
# 1606           sAleS EXECUtIvE                 1           NaN        4294,0
# 1608    MANUfaCtuRiNG DiReCtor                 1       Married        6725,0
# 1609           saLEs ExeCUTiVe                 4       Married       10325,0
# 1610     LAboRaTOry tECHNiCIAn                 2           NaN        4447,0
# 1612           SaLes ExecUtIVe                 4      Divorced           NaN
#
#        MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# index
# 1483         21437                   0      Y      NaN                 19
# 1484         15346                   6      Y      NaN                 14
# 1486         21445                   9    NaN       No                 17
# 1487         25326                   1      Y      Yes                 11
# 1488         21981                   0    NaN       No                 12
# ...            ...                 ...    ...      ...                ...
# 1606         11148                   1      Y      NaN                 12
# 1608         13554                   1    NaN      NaN                 12
# 1609          5518                   1      Y      NaN                 11
# 1610         23163                   1    NaN      NaN                 12
# 1612         25952                   4    NaN       No                 13
#
#       PerformanceRating  RelationshipSatisfaction StandardHours  \
# index
# 1483                3,0                         4           NaN
# 1484                3,0                         2           NaN
# 1486                3,0                         4          80,0
# 1487                3,0                         3          80,0
# 1488                NaN                         1           NaN
# ...                 ...                       ...           ...
# 1606                3,0                         2           NaN
# 1608                3,0                         3           NaN
# 1609                NaN                         1           NaN
# 1610                3,0                         2           NaN
# 1612                NaN                         4           NaN
#
#        StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# index
# 1483                  0               NaN                      2
# 1484                  1               6,0                      2
# 1486                  2              23,0                      0
# 1487                  0               2,0                      6
# 1488                  1               3,0                      4
# ...                 ...               ...                    ...
# 1606                  0               NaN                      2
# 1608                  1               8,0                      2
# 1609                  1               NaN                      6
# 1610                  0               NaN                      5
# 1612                  2              12,0                      3
#
#       WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# index
# 1483              2,0               2                NaN
# 1484              3,0               3                NaN
# 1486              3,0               2                NaN
# 1487              4,0               2                NaN
# 1488              3,0               2                NaN
# ...               ...             ...                ...
# 1606              3,0               7                NaN
# 1608              4,0               8                NaN
# 1609              3,0              16                NaN
# 1610              2,0               9                NaN
# 1612              3,0               7                NaN
#
#        YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# index
# 1483                         2                     2                 NaN
# 1484                         1                     2              2042,0
# 1486                         2                     2                 NaN
# 1487                         2                     2              2070,0
# 1488                         2                     2              2791,0
# ...                        ...                   ...                 ...
# 1606                         0                     7              4294,0
# 1608                         6                     3              6725,0
# 1609                         3                     7             10325,0
# 1610                         0                     8              4447,0
# 1612                         0                     7                 NaN
#
#        DateBirth       Salary                   RoleDepartament  \
# index
# 1483        1990  1000000000$   sales repResENTaTiVE  -  Sales
# 1484        1997  1000000000$                               NaN
# 1486        1977  1000000000$                               NaN
# 1487        2002  1000000000$                               NaN
# 1488        1992  1000000000$                               NaN
# ...          ...          ...                               ...
# 1606        1997  1000000000$        sAleS EXECUtIvE  -  Sales
# 1608        1991  1000000000$                               NaN
# 1609        1987  1000000000$                               NaN
# 1610        1978  1000000000$                               NaN
# 1612        1987  1000000000$                               NaN
#
#        NUMBERCHILDREN RemoteWork
# index
# 1483              NaN          0
# 1484              NaN        Yes
# 1486              NaN          1
# 1487              NaN          1
# 1488              NaN      False
# ...               ...        ...
# 1606              NaN          1
# 1608              NaN          1
# 1609              NaN          0
# 1610              NaN          1
# 1612              NaN       True
#
# [104 rows x 41 columns]

# %%
# Restaurar el orden original 
df_unique = df_unique.sort_index()
# Remover el nombre del indice
df_unique.index.name = None

# %%
df_unique['employeenumber'].duplicated().sum()
# Out:
# 0

# %%
df_unique # Este es el df resultante que tiene las filas que queremos mantener en el df completo.
# Out:
#      Age Attrition     BusinessTravel DailyRate Department  DistanceFromHome  \
# 1470  34        No      travel_rarely   1440,0$        NaN                 7
# 1471  28        No         non-travel   1103,0$        NaN                16
# 1472  29        No                NaN    136,0$        NaN                 1
# 1474  38        No                NaN    119,0$        NaN                 3
# 1476  55        No      travel_rarely    452,0$        NaN                 1
# ...   ..       ...                ...       ...        ...               ...
# 1606  26        No  travel_frequently   1283,0$     Sales                  1
# 1608  32        No                NaN    498,0$        NaN                 3
# 1609  36       Yes      travel_rarely    530,0$        NaN                 3
# 1610  45        No         non-travel    805,0$        NaN                 4
# 1612  36        No         non-travel   1229,0$        NaN                 8
#
#       Education    EducationField  employeecount employeenumber  \
# 1470          2  Technical Degree              1         1541,0
# 1471          3           Medical              1         1947,0
# 1472          3     Life Sciences              1         1954,0
# 1474          3     Life Sciences              1          307,0
# 1476          3           Medical              1          374,0
# ...         ...               ...            ...            ...
# 1606          3           Medical              1          956,0
# 1608          4           Medical              1          966,0
# 1609          1     Life Sciences              1          967,0
# 1610          2               NaN              1          972,0
# 1612          4  Technical Degree              1          990,0
#
#       EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 1470                        2       0         55               3         1
# 1471                        3       0         49               3         1
# 1472                        1       0         89               3         2
# 1474                        1       0         76               3         3
# 1476                        4       0         81               3         5
# ...                       ...     ...        ...             ...       ...
# 1606                        3       0         52               2         2
# 1608                        3       1         93               3         2
# 1609                        3       0         51               2         3
# 1610                        3       0         57               3         2
# 1612                        1       0         84               3         2
#
#                           JobRole  JobSatisfaction MaritalStatus  \
# 1470        saLeS RePreseNTAtIve                 3           NaN
# 1471          ReSearCH ScIEntISt                 3        Single
# 1472   HeALTHcare repREsEnTAtivE                 1       Married
# 1474             SAleS EXeCuTive                 3      Divorced
# 1476                     MaNAger                 1        Single
# ...                           ...              ...           ...
# 1606             sAleS EXECUtIvE                 1           NaN
# 1608      MANUfaCtuRiNG DiReCtor                 1       Married
# 1609             saLEs ExeCUTiVe                 4       Married
# 1610       LAboRaTOry tECHNiCIAn                 2           NaN
# 1612             SaLes ExecUtIVe                 4      Divorced
#
#      MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  \
# 1470        2308,0         4944                   0    NaN      Yes
# 1471        2144,0         2122                   1    NaN       No
# 1472        5373,0         6225                   0      Y       No
# 1474           NaN         9647                   0      Y      NaN
# 1476       19045,0        18938                   0      Y      NaN
# ...            ...          ...                 ...    ...      ...
# 1606        4294,0        11148                   1      Y      NaN
# 1608        6725,0        13554                   1    NaN      NaN
# 1609       10325,0         5518                   1      Y      NaN
# 1610        4447,0        23163                   1    NaN      NaN
# 1612           NaN        25952                   4    NaN       No
#
#       PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 1470                 25               4,0                         2
# 1471                 14               3,0                         3
# 1472                 12               3,0                         1
# 1474                 12               3,0                         3
# 1476                 14               3,0                         3
# ...                 ...               ...                       ...
# 1606                 12               3,0                         2
# 1608                 12               3,0                         3
# 1609                 11               NaN                         1
# 1610                 12               3,0                         2
# 1612                 13               NaN                         4
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 1470           NaN                 1              12,0                      4
# 1471           NaN                 0               5,0                      3
# 1472           NaN                 1               6,0                      5
# 1474           NaN                 2               NaN                      6
# 1476           NaN                 0              37,0                      2
# ...            ...               ...               ...                    ...
# 1606           NaN                 0               NaN                      2
# 1608           NaN                 1               8,0                      2
# 1609           NaN                 1               NaN                      6
# 1610           NaN                 0               NaN                      5
# 1612           NaN                 2              12,0                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 1470             3,0              11                NaN
# 1471             2,0               5                NaN
# 1472             2,0               5                NaN
# 1474             2,0              16                NaN
# 1476             3,0              36                NaN
# ...              ...             ...                ...
# 1606             3,0               7                NaN
# 1608             4,0               8                NaN
# 1609             3,0              16                NaN
# 1610             2,0               9                NaN
# 1612             3,0               7                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 1470                        5                     7              2308,0
# 1471                        1                     4              2144,0
# 1472                        0                     2              5373,0
# 1474                        5                    13                 NaN
# 1476                        4                    13             19045,0
# ...                       ...                   ...                 ...
# 1606                        0                     7              4294,0
# 1608                        6                     3              6725,0
# 1609                        3                     7             10325,0
# 1610                        0                     8              4447,0
# 1612                        0                     7                 NaN
#
#       DateBirth       Salary              RoleDepartament  NUMBERCHILDREN  \
# 1470       1989  1000000000$                          NaN             NaN
# 1471       1995  1000000000$                          NaN             NaN
# 1472       1994  1000000000$                          NaN             NaN
# 1474       1985  1000000000$                          NaN             NaN
# 1476       1968  1000000000$                          NaN             NaN
# ...         ...          ...                          ...             ...
# 1606       1997  1000000000$   sAleS EXECUtIvE  -  Sales              NaN
# 1608       1991  1000000000$                          NaN             NaN
# 1609       1987  1000000000$                          NaN             NaN
# 1610       1978  1000000000$                          NaN             NaN
# 1612       1987  1000000000$                          NaN             NaN
#
#      RemoteWork
# 1470          1
# 1471      False
# 1472          0
# 1474        Yes
# 1476        Yes
# ...         ...
# 1606          1
# 1608          1
# 1609          0
# 1610          1
# 1612       True
#
# [104 rows x 41 columns]
