# %%
# Libraries 
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np
from auto_eda import AutoEDA
import warnings

# Configuration
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# pd.set_option('display.max_rows', None)
warnings.filterwarnings("ignore")

# %%
eda = AutoEDA()
df = eda.read_file('../hr_data_transformed_2024-08-02_16:14:18.csv')
eda.explo_df(df)
# Out:
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1614 non-null   int64
#  1   attrition                   1614 non-null   object
#  2   business_travel             1614 non-null   object
#  3   daily_rate                  1614 non-null   float64
#  4   department                  1614 non-null   object
#  5   distance_from_home          1614 non-null   int64
#  6   education                   1614 non-null   int64
#  7   education_field             1614 non-null   object
#  8   employee_number             1614 non-null   object
#  9   environment_satisfaction    1614 non-null   float64
#  10  gender                      1614 non-null   object
#  11  hourly_rate                 1614 non-null   float64
#  12  job_involvement             1614 non-null   int64
#  13  job_level                   1614 non-null   int64
#  14  job_role                    1614 non-null   object
#  15  job_satisfaction            1614 non-null   int64
#  16  marital_status              1614 non-null   object
#  17  monthly_income              1614 non-null   float64
#  18  monthly_rate                1614 non-null   int64
#  19  num_companies_worked        1614 non-null   int64
#  20  over_time                   1614 non-null   object
#  21  percent_salary_hike         1614 non-null   int64
#  22  performance_rating          1614 non-null   float64
#  23  relationship_satisfaction   1614 non-null   int64
#  24  stock_option_level          1614 non-null   int64
#  25  total_working_years         1614 non-null   float64
#  26  training_times_last_year    1614 non-null   int64
#  27  work_life_balance           1614 non-null   float64
#  28  years_at_company            1614 non-null   int64
#  29  years_since_last_promotion  1614 non-null   int64
#  30  years_with_curr_manager     1614 non-null   int64
#  31  date_birth                  1614 non-null   int64
#  32  remote_work                 1614 non-null   object
# dtypes: float64(7), int64(16), object(10)
# memory usage: 428.7+ KB
# None
# First 10 rows of the DataFrame:
#    age attrition    business_travel  daily_rate              department  \
# 0   51        No            Unknown       684.0  Research & Development
# 1   52        No            Unknown       699.0                 Unknown
# 2   42        No      travel_rarely       532.0  Research & Development
# 3   47        No      travel_rarely       359.0  Research & Development
# 4   46        No            Unknown      1319.0                   Sales
# 5   48        No            Unknown       117.0  Research & Development
# 6   59        No            Unknown      1435.0                   Sales
# 7   42        No      travel_rarely       635.0                   Sales
# 8   41        No            Unknown      1276.0                 Unknown
# 9   41        No  travel_frequently       840.0  Research & Development
#
#    distance_from_home  education   education_field employee_number  \
# 0                   6          3           Unknown           162.0
# 1                   1          4     Life Sciences           259.0
# 2                   4          2  Technical Degree           319.0
# 3                   2          4           Medical         Unknown
# 4                   3          3  Technical Degree         Unknown
# 5                  22          3           Medical          1900.0
# 6                  25          3     Life Sciences            81.0
# 7                   1          1           Unknown           387.0
# 8                   2          5           Unknown         Unknown
# 9                   9          3           Unknown           999.0
#
#    environment_satisfaction  gender  hourly_rate  job_involvement  job_level  \
# 0                       1.0    Male         51.0                3          5
# 1                       3.0    Male         65.0                2          5
# 2                       3.0    Male         58.0                3          5
# 3                       1.0  Female         82.0                3          4
# 4                       1.0  Female         45.0                4          4
# 5                       4.0  Female         58.0                3          4
# 6                       1.0  Female         99.0                3          3
# 7                       2.0    Male         99.0                3          2
# 8                       2.0  Female         91.0                3          4
# 9                       1.0    Male         64.0                3          5
#
#             job_role  job_satisfaction marital_status  monthly_income  \
# 0  Research Director                 3        Unknown         19537.0
# 1            Manager                 3        Unknown         19999.0
# 2            Manager                 4        Married         19232.0
# 3  Research Director                 3        Married         17169.0
# 4    Sales Executive                 1       Divorced          5820.5
# 5            Manager                 4        Unknown         17174.0
# 6    Sales Executive                 1        Unknown          5820.5
# 7    Sales Executive                 3        Married          5820.5
# 8            Manager                 1        Married         16595.0
# 9  Research Director                 3        Unknown         16704.0
#
#    monthly_rate  num_companies_worked over_time  percent_salary_hike  \
# 0          6462                     7        No                   13
# 1          5678                     0   Unknown                   14
# 2          4933                     1        No                   11
# 3         26703                     3   Unknown                   19
# 4          7739                     2        No                   12
# 5          2437                     3        No                   11
# 6          2354                     7   Unknown                   11
# 7         24532                     1        No                   25
# 8          5626                     7        No                   16
# 9          3735                     2        No                   17
#
#    performance_rating  relationship_satisfaction  stock_option_level  \
# 0                 3.0                          3                   0
# 1                 3.0                          1                   1
# 2                 3.0                          4                   0
# 3                 3.0                          2                   2
# 4                 3.0                          4                   1
# 5                 3.0                          2                   1
# 6                 3.0                          4                   0
# 7                 4.0                          3                   0
# 8                 3.0                          2                   1
# 9                 3.0                          2                   1
#
#    total_working_years  training_times_last_year  work_life_balance  \
# 0            11.318934                         5                3.0
# 1            34.000000                         5                3.0
# 2            22.000000                         3                3.0
# 3            11.318934                         2                3.0
# 4            11.318934                         5                3.0
# 5            11.318934                         3                3.0
# 6            28.000000                         3                2.0
# 7            20.000000                         3                3.0
# 8            22.000000                         2                3.0
# 9            21.000000                         2                4.0
#
#    years_at_company  years_since_last_promotion  years_with_curr_manager  \
# 0                20                          15                       15
# 1                33                          11                        9
# 2                22                          11                       15
# 3                20                           5                        6
# 4                19                           2                        8
# 5                22                           4                        7
# 6                21                           7                        9
# 7                20                          11                        6
# 8                18                          11                        8
# 9                18                           0                       11
#
#    date_birth remote_work
# 0        1972        True
# 1        1971           1
# 2        1981           1
# 3        1976       False
# 4        1977           0
# 5        1975        True
# 6        1964        True
# 7        1981           0
# 8        1982        True
# 9        1982           0
# Last 10 rows of the DataFrame:
#       age attrition    business_travel  daily_rate              department  \
# 1604   41       Yes            Unknown      1085.0  Research & Development
# 1605   31        No      travel_rarely       154.0                   Sales
# 1606   26        No  travel_frequently      1283.0                   Sales
# 1607   31        No            Unknown       616.0  Research & Development
# 1608   32        No            Unknown       498.0  Research & Development
# 1609   36       Yes      travel_rarely       530.0                   Sales
# 1610   45        No         non-travel       805.0  Research & Development
# 1611   39        No      travel_rarely       903.0                   Sales
# 1612   36        No         non-travel      1229.0                   Sales
# 1613   46        No            Unknown       566.0  Research & Development
#
#       distance_from_home  education   education_field employee_number  \
# 1604                   2          4     Life Sciences           927.0
# 1605                   7          4           Unknown           941.0
# 1606                   1          3           Medical           956.0
# 1607                  12          3           Medical         Unknown
# 1608                   3          4           Medical           966.0
# 1609                   3          1     Life Sciences           967.0
# 1610                   4          2           Unknown           972.0
# 1611                  13          5           Unknown         Unknown
# 1612                   8          4  Technical Degree           990.0
# 1613                   7          2           Medical         Unknown
#
#       environment_satisfaction  gender  hourly_rate  job_involvement  \
# 1604                       2.0  Female    66.028105                1
# 1605                       2.0    Male    66.028105                2
# 1606                       3.0    Male    52.000000                2
# 1607                       4.0  Female    41.000000                3
# 1608                       3.0  Female    93.000000                3
# 1609                       3.0    Male    51.000000                2
# 1610                       3.0    Male    57.000000                3
# 1611                       3.0    Male    41.000000                4
# 1612                       1.0    Male    84.000000                3
# 1613                       4.0    Male    75.000000                3
#
#       job_level                   job_role  job_satisfaction marital_status  \
# 1604          1      Laboratory Technician                 4       Divorced
# 1605          1       Sales Representative                 3        Unknown
# 1606          2            Sales Executive                 1        Unknown
# 1607          2  Healthcare Representative                 4        Unknown
# 1608          2     Manufacturing Director                 1        Married
# 1609          3            Sales Executive                 4        Married
# 1610          2      Laboratory Technician                 2        Unknown
# 1611          3            Sales Executive                 3         Single
# 1612          2            Sales Executive                 4       Divorced
# 1613          3     Manufacturing Director                 3        Unknown
#
#       monthly_income  monthly_rate  num_companies_worked over_time  \
# 1604          3034.0         17725                     4       Yes
# 1605          2329.0         11737                     3   Unknown
# 1606          4294.0         11148                     1   Unknown
# 1607          6755.0         17369                     0   Unknown
# 1608          6725.0         13554                     1   Unknown
# 1609         10325.0          5518                     1   Unknown
# 1610          4447.0         23163                     1   Unknown
# 1611          5820.5          2560                     0        No
# 1612          5820.5         25952                     4        No
# 1613         10845.0         24208                     6   Unknown
#
#       percent_salary_hike  performance_rating  relationship_satisfaction  \
# 1604                   13                 3.0                          3
# 1605                   15                 3.0                          2
# 1606                   12                 3.0                          2
# 1607                   11                 3.0                          3
# 1608                   12                 3.0                          3
# 1609                   11                 3.0                          1
# 1610                   12                 3.0                          2
# 1611                   18                 3.0                          4
# 1612                   13                 3.0                          4
# 1613                   13                 3.0                          2
#
#       stock_option_level  total_working_years  training_times_last_year  \
# 1604                   1            11.318934                         1
# 1605                   0            11.318934                         2
# 1606                   0            11.318934                         2
# 1607                   2            10.000000                         2
# 1608                   1             8.000000                         2
# 1609                   1            11.318934                         6
# 1610                   0            11.318934                         5
# 1611                   0             9.000000                         3
# 1612                   2            12.000000                         3
# 1613                   1            11.318934                         3
#
#       work_life_balance  years_at_company  years_since_last_promotion  \
# 1604                2.0                 7                           1
# 1605                4.0                 7                           5
# 1606                3.0                 7                           0
# 1607                1.0                 9                           8
# 1608                4.0                 8                           6
# 1609                3.0                16                           3
# 1610                2.0                 9                           0
# 1611                3.0                 8                           0
# 1612                3.0                 7                           0
# 1613                3.0                 8                           0
#
#       years_with_curr_manager  date_birth remote_work
# 1604                        0        1982        True
# 1605                        2        1992        True
# 1606                        7        1997           1
# 1607                        5        1992        True
# 1608                        3        1991           1
# 1609                        7        1987           0
# 1610                        8        1978           1
# 1611                        7        1984        True
# 1612                        7        1987        True
# 1613                        7        1977           0
# Statistical description of the DataFrame (numeric):
#                              count          mean          std     min     25%  \
# age                         1614.0     36.920694     9.102157    18.0    30.0
# daily_rate                  1614.0    802.085235   387.437150   103.0   498.0
# distance_from_home          1614.0     11.141884    10.450560     1.0     2.0
# education                   1614.0      2.925031     1.022357     1.0     2.0
# environment_satisfaction    1614.0      2.731722     1.065969     1.0     2.0
# hourly_rate                 1614.0     66.028105    19.653316    30.0    49.0
# job_involvement             1614.0      2.739777     0.711567     1.0     2.0
# job_level                   1614.0      2.068154     1.101344     1.0     1.0
# job_satisfaction            1614.0      2.738538     1.106163     1.0     2.0
# monthly_income              1614.0   6318.565985  4633.155608  1009.0  3034.0
# monthly_rate                1614.0  14284.495663  7110.414585  2094.0  8001.0
# num_companies_worked        1614.0      2.673482     2.506152     0.0     1.0
# percent_salary_hike         1614.0     15.165428     3.648610    11.0    12.0
# performance_rating          1614.0      3.132590     0.339236     3.0     3.0
# relationship_satisfaction   1614.0      2.704461     1.079031     1.0     2.0
# stock_option_level          1614.0      0.791202     0.842396     0.0     0.0
# total_working_years         1614.0     11.318934     6.343755     0.0     8.0
# training_times_last_year    1614.0      2.809789     1.297765     0.0     2.0
# work_life_balance           1614.0      2.775713     0.681347     1.0     2.0
# years_at_company            1614.0      7.132590     6.124237     0.0     3.0
# years_since_last_promotion  1614.0      2.245973     3.235665     0.0     0.0
# years_with_curr_manager     1614.0      4.220570     3.562695     0.0     2.0
# date_birth                  1614.0   1986.076208     9.101332  1963.0  1980.0
#
#                                      50%           75%      max
# age                            36.000000     43.000000     60.0
# daily_rate                    802.085235   1130.750000   1499.0
# distance_from_home              8.000000     17.000000     49.0
# education                       3.000000      4.000000      5.0
# environment_satisfaction        3.000000      4.000000      4.0
# hourly_rate                    66.028105     83.000000    100.0
# job_involvement                 3.000000      3.000000      4.0
# job_level                       2.000000      3.000000      5.0
# job_satisfaction                3.000000      4.000000      4.0
# monthly_income               5384.500000   6755.000000  19999.0
# monthly_rate                14248.500000  20364.000000  26999.0
# num_companies_worked            2.000000      4.000000      9.0
# percent_salary_hike            14.000000     18.000000     25.0
# performance_rating              3.000000      3.000000      4.0
# relationship_satisfaction       3.000000      4.000000      4.0
# stock_option_level              1.000000      1.000000      3.0
# total_working_years            11.318934     11.318934     40.0
# training_times_last_year        3.000000      3.000000      6.0
# work_life_balance               3.000000      3.000000      4.0
# years_at_company                5.000000      9.000000     40.0
# years_since_last_promotion      1.000000      3.000000     15.0
# years_with_curr_manager         3.000000      7.000000     17.0
# date_birth                   1987.000000   1993.000000   2005.0
# Statistical description of the DataFrame (categorical):
#                 count unique                     top  freq
# attrition        1614      2                      No  1355
# business_travel  1614      4                 Unknown   772
# department       1614      4  Research & Development  1001
# education_field  1614      7                 Unknown   745
# employee_number  1614   1080                 Unknown   431
# gender           1614      2                    Male   971
# job_role         1614      9         Sales Executive   369
# marital_status   1614      4                 Unknown   651
# over_time        1614      3                      No   682
# remote_work      1614      4                    True   640
# Count of null values per column:
# age                           0
# attrition                     0
# business_travel               0
# daily_rate                    0
# department                    0
# distance_from_home            0
# education                     0
# education_field               0
# employee_number               0
# environment_satisfaction      0
# gender                        0
# hourly_rate                   0
# job_involvement               0
# job_level                     0
# job_role                      0
# job_satisfaction              0
# marital_status                0
# monthly_income                0
# monthly_rate                  0
# num_companies_worked          0
# over_time                     0
# percent_salary_hike           0
# performance_rating            0
# relationship_satisfaction     0
# stock_option_level            0
# total_working_years           0
# training_times_last_year      0
# work_life_balance             0
# years_at_company              0
# years_since_last_promotion    0
# years_with_curr_manager       0
# date_birth                    0
# remote_work                   0
# dtype: int64
# Percentage of null values per column (only columns with nulls):
# Series([], dtype: float64)
# Rows with all values as null:
# There is no rows with all values as null.
#
# Count of duplicate rows:
# 32

# %%
df.columns
# Out:
# Index(['age', 'attrition', 'business_travel', 'daily_rate', 'department',
#        'distance_from_home', 'education', 'education_field', 'employee_number',
#        'environment_satisfaction', 'gender', 'hourly_rate', 'job_involvement',
#        'job_level', 'job_role', 'job_satisfaction', 'marital_status',
#        'monthly_income', 'monthly_rate', 'num_companies_worked', 'over_time',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'total_working_years', 'training_times_last_year', 'work_life_balance',
#        'years_at_company', 'years_since_last_promotion',
#        'years_with_curr_manager', 'date_birth', 'remote_work'],
#       dtype='object')

# %%
eda.explo_df(df, 'remote_work')
# Out:
# Exploration of the column: remote_work
#
# Statistical description (categorical):
# count     1614
# unique       4
# top       True
# freq       640
# Name: remote_work, dtype: object
# Count of null values: 0
#
# Unique values: ['True' '1' 'False' '0']
#
# Value Counts: remote_work
# True     640
# 1        360
# 0        309
# False    305
# Name: count, dtype: int64
#
# Count of duplicates in the column: 1610

# %%
df_corr = (eda.identify_correlations(df))['spearman'] # Returns dict with pearce or spearman method as key and df as value
df_corr
# Out:
#                             job_level  date_birth  total_working_years  \
# job_level                    1.000000   -0.486174             0.539274
# date_birth                  -0.486174    1.000000            -0.496206
# total_working_years          0.539274   -0.496206             1.000000
# age                          0.486043   -0.999812             0.495533
# stock_option_level           0.050809   -0.057243             0.049877
# job_satisfaction            -0.012870    0.010555            -0.013525
# distance_from_home           0.016072    0.018656            -0.031306
# work_life_balance            0.023320    0.011002             0.000916
# num_companies_worked         0.174150   -0.338485             0.259142
# hourly_rate                 -0.031613   -0.024286            -0.007837
# environment_satisfaction     0.008932   -0.014283             0.023021
# years_at_company             0.476567   -0.253255             0.426251
# years_with_curr_manager      0.366739   -0.189713             0.353521
# monthly_rate                 0.047035   -0.024798             0.035871
# education                    0.103286   -0.199620             0.107546
# daily_rate                   0.000118    0.004816             0.051017
# job_involvement             -0.003778   -0.041914             0.020526
# performance_rating          -0.019569   -0.001854            -0.005737
# percent_salary_hike         -0.037048   -0.012821            -0.036908
# years_since_last_promotion   0.255848   -0.170695             0.254677
# monthly_income               0.877742   -0.431469             0.481800
# training_times_last_year    -0.025442    0.012119            -0.032037
# relationship_satisfaction    0.008850   -0.046433             0.009829
#
#                                  age  stock_option_level  job_satisfaction  \
# job_level                   0.486043            0.050809         -0.012870
# date_birth                 -0.999812           -0.057243          0.010555
# total_working_years         0.495533            0.049877         -0.013525
# age                         1.000000            0.057739         -0.010174
# stock_option_level          0.057739            1.000000          0.016304
# job_satisfaction           -0.010174            0.016304          1.000000
# distance_from_home         -0.018802            0.043674          0.007592
# work_life_balance          -0.010325           -0.020403         -0.034898
# num_companies_worked        0.338368            0.040901         -0.053438
# hourly_rate                 0.024718            0.046613         -0.068980
# environment_satisfaction    0.014213            0.012867          0.008568
# years_at_company            0.254005            0.060047          0.010673
# years_with_curr_manager     0.190263            0.053066         -0.017182
# monthly_rate                0.024349           -0.022409          0.002086
# education                   0.199142            0.008219         -0.001681
# daily_rate                 -0.005419            0.031766          0.040163
# job_involvement             0.041730            0.048506         -0.010614
# performance_rating          0.002038            0.017079         -0.008186
# percent_salary_hike         0.013307            0.021321          0.032164
# years_since_last_promotion  0.171217            0.033639          0.009088
# monthly_income              0.431576            0.049341         -0.015675
# training_times_last_year   -0.011728            0.001641         -0.001101
# relationship_satisfaction   0.045807           -0.058555         -0.009525
#
#                             distance_from_home  work_life_balance  \
# job_level                             0.016072           0.023320
# date_birth                            0.018656           0.011002
# total_working_years                  -0.031306           0.000916
# age                                  -0.018802          -0.010325
# stock_option_level                    0.043674          -0.020403
# job_satisfaction                      0.007592          -0.034898
# distance_from_home                    1.000000          -0.039366
# work_life_balance                    -0.039366           1.000000
# num_companies_worked                  0.022006           0.003745
# hourly_rate                           0.018974          -0.028662
# environment_satisfaction             -0.001102           0.051950
# years_at_company                     -0.015424          -0.002718
# years_with_curr_manager              -0.014242          -0.015137
# monthly_rate                          0.019217           0.007886
# education                             0.005726           0.029773
# daily_rate                            0.011909          -0.042170
# job_involvement                       0.028308          -0.021999
# performance_rating                    0.021294           0.015914
# percent_salary_hike                   0.048240           0.006573
# years_since_last_promotion           -0.024378          -0.000179
# monthly_income                       -0.017743           0.021591
# training_times_last_year             -0.052078           0.012783
# relationship_satisfaction             0.005338           0.007458
#
#                             num_companies_worked  hourly_rate  \
# job_level                               0.174150    -0.031613
# date_birth                             -0.338485    -0.024286
# total_working_years                     0.259142    -0.007837
# age                                     0.338368     0.024718
# stock_option_level                      0.040901     0.046613
# job_satisfaction                       -0.053438    -0.068980
# distance_from_home                      0.022006     0.018974
# work_life_balance                       0.003745    -0.028662
# num_companies_worked                    1.000000     0.033235
# hourly_rate                             0.033235     1.000000
# environment_satisfaction               -0.007278    -0.066883
# years_at_company                       -0.178405    -0.028099
# years_with_curr_manager                -0.152027    -0.009649
# monthly_rate                            0.029916     0.013310
# education                               0.122867     0.008071
# daily_rate                              0.033994     0.026720
# job_involvement                         0.024892     0.040708
# performance_rating                      0.000185     0.001147
# percent_salary_hike                     0.003944    -0.025771
# years_since_last_promotion             -0.072908    -0.036023
# monthly_income                          0.157471    -0.005292
# training_times_last_year               -0.061361    -0.002464
# relationship_satisfaction               0.054319     0.008852
#
#                             environment_satisfaction  years_at_company  \
# job_level                                   0.008932          0.476567
# date_birth                                 -0.014283         -0.253255
# total_working_years                         0.023021          0.426251
# age                                         0.014213          0.254005
# stock_option_level                          0.012867          0.060047
# job_satisfaction                            0.008568          0.010673
# distance_from_home                         -0.001102         -0.015424
# work_life_balance                           0.051950         -0.002718
# num_companies_worked                       -0.007278         -0.178405
# hourly_rate                                -0.066883         -0.028099
# environment_satisfaction                    1.000000          0.009019
# years_at_company                            0.009019          1.000000
# years_with_curr_manager                     0.001237          0.834672
# monthly_rate                                0.042949         -0.027006
# education                                  -0.036920          0.064417
# daily_rate                                  0.016599         -0.018651
# job_involvement                            -0.017798          0.021764
# performance_rating                         -0.025755          0.008545
# percent_salary_hike                        -0.041281         -0.051566
# years_since_last_promotion                  0.035504          0.507177
# monthly_income                              0.001865          0.429210
# training_times_last_year                   -0.045044          0.007897
# relationship_satisfaction                   0.012510         -0.010724
#
#                             years_with_curr_manager  monthly_rate  education  \
# job_level                                  0.366739      0.047035   0.103286
# date_birth                                -0.189713     -0.024798  -0.199620
# total_working_years                        0.353521      0.035871   0.107546
# age                                        0.190263      0.024349   0.199142
# stock_option_level                         0.053066     -0.022409   0.008219
# job_satisfaction                          -0.017182      0.002086  -0.001681
# distance_from_home                        -0.014242      0.019217   0.005726
# work_life_balance                         -0.015137      0.007886   0.029773
# num_companies_worked                      -0.152027      0.029916   0.122867
# hourly_rate                               -0.009649      0.013310   0.008071
# environment_satisfaction                   0.001237      0.042949  -0.036920
# years_at_company                           0.834672     -0.027006   0.064417
# years_with_curr_manager                    1.000000     -0.028211   0.050812
# monthly_rate                              -0.028211      1.000000  -0.023739
# education                                  0.050812     -0.023739   1.000000
# daily_rate                                -0.008777     -0.023062  -0.006305
# job_involvement                            0.050327     -0.008818   0.036402
# performance_rating                         0.017938     -0.026454  -0.035506
# percent_salary_hike                       -0.018876     -0.011475   0.008786
# years_since_last_promotion                 0.450930     -0.017603   0.041675
# monthly_income                             0.331165      0.049634   0.098160
# training_times_last_year                   0.003032     -0.013342  -0.035741
# relationship_satisfaction                 -0.006656     -0.002135  -0.019888
#
#                             daily_rate  job_involvement  performance_rating  \
# job_level                     0.000118        -0.003778           -0.019569
# date_birth                    0.004816        -0.041914           -0.001854
# total_working_years           0.051017         0.020526           -0.005737
# age                          -0.005419         0.041730            0.002038
# stock_option_level            0.031766         0.048506            0.017079
# job_satisfaction              0.040163        -0.010614           -0.008186
# distance_from_home            0.011909         0.028308            0.021294
# work_life_balance            -0.042170        -0.021999            0.015914
# num_companies_worked          0.033994         0.024892            0.000185
# hourly_rate                   0.026720         0.040708            0.001147
# environment_satisfaction      0.016599        -0.017798           -0.025755
# years_at_company             -0.018651         0.021764            0.008545
# years_with_curr_manager      -0.008777         0.050327            0.017938
# monthly_rate                 -0.023062        -0.008818           -0.026454
# education                    -0.006305         0.036402           -0.035506
# daily_rate                    1.000000         0.051786           -0.011070
# job_involvement               0.051786         1.000000           -0.013405
# performance_rating           -0.011070        -0.013405            1.000000
# percent_salary_hike           0.022859        -0.005998            0.580230
# years_since_last_promotion   -0.042683        -0.006973            0.007717
# monthly_income                0.025939        -0.004117           -0.028680
# training_times_last_year     -0.013857         0.006675           -0.026812
# relationship_satisfaction     0.015182         0.038432           -0.004027
#
#                             percent_salary_hike  years_since_last_promotion  \
# job_level                             -0.037048                    0.255848
# date_birth                            -0.012821                   -0.170695
# total_working_years                   -0.036908                    0.254677
# age                                    0.013307                    0.171217
# stock_option_level                     0.021321                    0.033639
# job_satisfaction                       0.032164                    0.009088
# distance_from_home                     0.048240                   -0.024378
# work_life_balance                      0.006573                   -0.000179
# num_companies_worked                   0.003944                   -0.072908
# hourly_rate                           -0.025771                   -0.036023
# environment_satisfaction              -0.041281                    0.035504
# years_at_company                      -0.051566                    0.507177
# years_with_curr_manager               -0.018876                    0.450930
# monthly_rate                          -0.011475                   -0.017603
# education                              0.008786                    0.041675
# daily_rate                             0.022859                   -0.042683
# job_involvement                       -0.005998                   -0.006973
# performance_rating                     0.580230                    0.007717
# percent_salary_hike                    1.000000                   -0.050944
# years_since_last_promotion            -0.050944                    1.000000
# monthly_income                        -0.044594                    0.231973
# training_times_last_year              -0.006180                    0.010154
# relationship_satisfaction             -0.034276                    0.030819
#
#                             monthly_income  training_times_last_year  \
# job_level                         0.877742                 -0.025442
# date_birth                       -0.431469                  0.012119
# total_working_years               0.481800                 -0.032037
# age                               0.431576                 -0.011728
# stock_option_level                0.049341                  0.001641
# job_satisfaction                 -0.015675                 -0.001101
# distance_from_home               -0.017743                 -0.052078
# work_life_balance                 0.021591                  0.012783
# num_companies_worked              0.157471                 -0.061361
# hourly_rate                      -0.005292                 -0.002464
# environment_satisfaction          0.001865                 -0.045044
# years_at_company                  0.429210                  0.007897
# years_with_curr_manager           0.331165                  0.003032
# monthly_rate                      0.049634                 -0.013342
# education                         0.098160                 -0.035741
# daily_rate                        0.025939                 -0.013857
# job_involvement                  -0.004117                  0.006675
# performance_rating               -0.028680                 -0.026812
# percent_salary_hike              -0.044594                 -0.006180
# years_since_last_promotion        0.231973                  0.010154
# monthly_income                    1.000000                 -0.035546
# training_times_last_year         -0.035546                  1.000000
# relationship_satisfaction         0.003484                 -0.000228
#
#                             relationship_satisfaction
# job_level                                    0.008850
# date_birth                                  -0.046433
# total_working_years                          0.009829
# age                                          0.045807
# stock_option_level                          -0.058555
# job_satisfaction                            -0.009525
# distance_from_home                           0.005338
# work_life_balance                            0.007458
# num_companies_worked                         0.054319
# hourly_rate                                  0.008852
# environment_satisfaction                     0.012510
# years_at_company                            -0.010724
# years_with_curr_manager                     -0.006656
# monthly_rate                                -0.002135
# education                                   -0.019888
# daily_rate                                   0.015182
# job_involvement                              0.038432
# performance_rating                          -0.004027
# percent_salary_hike                         -0.034276
# years_since_last_promotion                   0.030819
# monthly_income                               0.003484
# training_times_last_year                    -0.000228
# relationship_satisfaction                    1.000000

# %%
eda.classify_correlations(df_corr)
# Out:
# Weak Correlations:
# Between job_level and num_companies_worked: 0.17
# Between job_level and education: 0.10
# Between job_level and years_since_last_promotion: 0.26
# Between date_birth and years_at_company: -0.25
# Between date_birth and years_with_curr_manager: -0.19
# Between date_birth and education: -0.20
# Between date_birth and years_since_last_promotion: -0.17
# Between total_working_years and num_companies_worked: 0.26
# Between total_working_years and education: 0.11
# Between total_working_years and years_since_last_promotion: 0.25
# Between age and years_at_company: 0.25
# Between age and years_with_curr_manager: 0.19
# Between age and education: 0.20
# Between age and years_since_last_promotion: 0.17
# Between num_companies_worked and years_at_company: -0.18
# Between num_companies_worked and years_with_curr_manager: -0.15
# Between num_companies_worked and education: 0.12
# Between num_companies_worked and monthly_income: 0.16
# Between years_since_last_promotion and monthly_income: 0.23
#
# Moderate Correlations:
# Between job_level and date_birth: -0.49
# Between job_level and total_working_years: 0.54
# Between job_level and age: 0.49
# Between job_level and years_at_company: 0.48
# Between job_level and years_with_curr_manager: 0.37
# Between date_birth and total_working_years: -0.50
# Between date_birth and num_companies_worked: -0.34
# Between date_birth and monthly_income: -0.43
# Between total_working_years and age: 0.50
# Between total_working_years and years_at_company: 0.43
# Between total_working_years and years_with_curr_manager: 0.35
# Between total_working_years and monthly_income: 0.48
# Between age and num_companies_worked: 0.34
# Between age and monthly_income: 0.43
# Between years_at_company and years_since_last_promotion: 0.51
# Between years_at_company and monthly_income: 0.43
# Between years_with_curr_manager and years_since_last_promotion: 0.45
# Between years_with_curr_manager and monthly_income: 0.33
# Between performance_rating and percent_salary_hike: 0.58
#
# Strong Correlations:
# Between job_level and monthly_income: 0.88
# Between date_birth and age: -1.00
# Between years_at_company and years_with_curr_manager: 0.83

# %%
eda.plot_histogram(df, 'years_with_curr_manager')

# %%
eda.plot_scatter(df, 'years_with_curr_manager', 'years_at_company')

# %%
eda.visualize_pairplot(df, ['years_at_company', 'years_since_last_promotion', 'job_level'], hue='marital_status')

# %%
eda.plot_boxplot(df, 'years_since_last_promotion')

# %%
eda.visualize_categorical_counts(df, ['business_travel', 'department', 'marital_status', 'remote_work'])

# %%
eda.visualize_facet_grid(df, col_names=['business_travel','job_role','department'], x_values=['daily_rate','monthly_income','total_working_years'], hue='gender')

# %%
df_heatmap1=df.groupby(['job_role','job_satisfaction']).monthly_income.mean().unstack(level=1)
df_heatmap2=df.groupby(['job_involvement','job_level']).monthly_rate.mean().unstack(level=1)

# %%
eda.visualize_general_statistics(df, df_heatmap1, df_heatmap2)

# %%
eda.visualize_pairplot(df, ['monthly_income','job_level','total_working_years','monthly_rate','age'], hue='gender')

# %%
df[['monthly_rate', 'monthly_income', 'hourly_rate', 'daily_rate']].reset_index()
# Out:
#       index  monthly_rate  monthly_income  hourly_rate  daily_rate
# 0         0          6462         19537.0         51.0       684.0
# 1         1          5678         19999.0         65.0       699.0
# 2         2          4933         19232.0         58.0       532.0
# 3         3         26703         17169.0         82.0       359.0
# 4         4          7739          5820.5         45.0      1319.0
# ...     ...           ...             ...          ...         ...
# 1609   1609          5518         10325.0         51.0       530.0
# 1610   1610         23163          4447.0         57.0       805.0
# 1611   1611          2560          5820.5         41.0       903.0
# 1612   1612         25952          5820.5         84.0      1229.0
# 1613   1613         24208         10845.0         75.0       566.0
#
# [1614 rows x 5 columns]

# %% [markdown]
# # NOTES / PREVIOUS CODES

# %%
grouped_stats = df.groupby('job_role')['monthly_income'].agg(['mean', 'median'])
round(grouped_stats, 2)
# Out:
#                                mean   median
# job_role
# Healthcare Representative   7726.84   6755.0
# Human Resources             4563.38   3712.5
# Laboratory Technician       3284.58   3034.0
# Manager                    17482.24  17982.5
# Manufacturing Director      7290.18   6397.0
# Research Director          16066.27  16704.0
# Research Scientist          3286.08   2906.5
# Sales Executive             6897.64   5820.5
# Sales Representative        2683.16   2430.0

# %%
def eda_summary(data):
    indexes = list(data.columns)
    cols = ['dtype', 'not_null_count', 'null_count', 'null_percent', 'duplicates', 'unique', 'top', 'freq', 'mean', 'std', 'min', 'max', '25%', '50%', '75%', 'description']

    data_eda = pd.DataFrame(index=indexes, columns=cols)

    descriptions = {
        'Age': 'La edad del empleado.',
        'Attrition': 'Indica si el empleado ha dejado la empresa ("No" significa que no ha dejado la empresa y "Yes" significa que ha dejado la empresa).',
        'BusinessTravel': 'Describe la frecuencia de los viajes relacionados con el trabajo del empleado (por ejemplo, "Travel_Rarely" para raramente).',
        'DailyRate': 'La tarifa diaria del empleado.',
        'Department': 'El departamento en el que trabaja el empleado (por ejemplo, "Research & Development", "Sales", etc.).',
        'DistanceFromHome': 'La distancia desde el hogar del empleado hasta su lugar de trabajo.',
        'Education': 'Nivel de educación del empleado (generalmente en una escala del 1 al 5).',
        'EducationField': 'El campo de educación del empleado.',
        'employeecount': 'Un contador que generalmente es 1 y se usa para contar empleados.',
        'employeenumber': 'Un número de identificación único para el empleado.',
        'EnvironmentSatisfaction': 'Nivel de satisfacción del empleado en relación con su entorno de trabajo. Con valores que estan comprendidos entre el 1 y el 4, siendo el 4 el nivel de máxima satisfacción.',
        'Gender': 'El género del empleado. Donde 0 corresponde con "hombre" y 1 con "mujer".',
        'HourlyRate': 'La tarifa por hora del empleado.',
        'JobInvolvement': 'Nivel de implicación del empleado en su trabajo.',
        'JobLevel': 'Nivel jerárquico del empleado en la empresa.',
        'JobRole': 'El rol o puesto de trabajo del empleado.',
        'JobSatisfaction': 'Nivel de satisfacción del empleado con su trabajo.',
        'MaritalStatus': 'El estado civil del empleado (por ejemplo, "Single", "Married", etc.).',
        'MonthlyIncome': 'Ingresos mensuales del empleado.',
        'MonthlyRate': 'Tasa mensual del empleado.',
        'NUMCOMPANIESWORKED': 'Número de compañías en las que el empleado ha trabajado.',
        'Over18': 'Indica si el empleado es mayor de 18 años.',
        'OverTime': 'Indica si el empleado trabaja horas extras ("Yes" para sí o "No" para no).',
        'PercentSalaryHike': 'El porcentaje de aumento salarial del empleado.',
        'PerformanceRating': 'Calificación de rendimiento del empleado.',
        'RelationshipSatisfaction': 'Nivel de satisfacción en las relaciones interpersonales del empleado.',
        'StandardHours': 'Las horas estándar de trabajo.',
        'StockOptionLevel': 'Nivel de opciones de compra de acciones del empleado.',
        'TOTALWORKINGYEARS': 'Total de años de experiencia laboral del empleado.',
        'TrainingTimesLastYear': 'Número de veces que el empleado recibió capacitación el año pasado.',
        'WORKLIFEBALANCE': 'Equilibrio entre trabajo y vida personal del empleado.',
        'YearsAtCompany': 'Años que el empleado ha trabajado en la empresa actual.',
        'YearsInCurrentRole': 'Años que el empleado ha estado en su puesto actual.',
        'YearsSinceLastPromotion': 'Años desde la última promoción del empleado.',
        'YEARSWITHCURRMANAGER': 'Años que el empleado ha estado bajo la supervisión del actual gerente.',
        'SameAsMonthlyIncome': 'Ingresos mensuales del empleado.',
        'DateBirth': 'Año de nacimiento del empleado (teniendo en cuenta que los datos fueron recogidos en el 2023).',
        'Salary': 'Salario de los empleados.',
        'RoleDepartament': 'El departamento y el rol del empleado.',
        'NUMBERCHILDREN': 'Número de hijos de los empleados.',
        'RemoteWork': 'Si el empleado puede teletrabajar o no.'
    }

    for var in indexes:
        data_eda.loc[var, 'dtype'] = data[var].dtype
        data_eda.loc[var, 'not_null_count'] = data[var].notnull().sum()
        data_eda.loc[var, 'null_count'] = data[var].isnull().sum()
        data_eda.loc[var, 'null_percent'] = str(round((data[var].isnull().sum() / len(data)) * 100, 2)) + '%'
        data_eda.loc[var, 'duplicates'] = data[var].duplicated().sum()
        data_eda.loc[var, 'unique'] = data[var].nunique() # if data[var].dtype == 'object' else None
        data_eda.loc[var, 'top'] = data[var].mode().iloc[0] if not data[var].mode().empty else None
        data_eda.loc[var, 'freq'] = data[var].value_counts().max() if not data[var].mode().empty else None
        data_eda.loc[var, 'mean'] = data[var].mean() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'std'] = data[var].std() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'min'] = data[var].min() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'max'] = data[var].max() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, '25%'] = data[var].quantile(0.25) if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, '50%'] = data[var].median() if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, '75%'] = data[var].quantile(0.75) if data[var].dtype in ['int64', 'float64'] else None
        data_eda.loc[var, 'description'] = descriptions.get(var, 'No description available')

    return data_eda

# %%
df_initial_eda = eda_summary(df)

# Description column left alignment
df_initial_eda['description'] = df_initial_eda['description'].apply(lambda x: f'{x:<}')

df_initial_eda = df_initial_eda.style.set_table_styles({
    'description': [{'selector': '', 'props': [('text-align', 'left')]}]
})

df_initial_eda = df_initial_eda.set_table_styles({
    'description': [{'selector': 'th', 'props': [('text-align', 'left')]}]
}, overwrite=False)

df_initial_eda

# %% [markdown]
# # Eliminando duplicados de la columna employeenumber

# %%
df.loc[df['employeenumber'].duplicated(keep=False), :].sort_values(by='employeenumber')

# %%
duplicados = df.loc[df['employeenumber'].duplicated(keep=False), :].sort_values(by='employeenumber')
duplicados.shape # Nos llama la atención que haya 639 duplicados cuando el número de duplicados debería ser par.
# Out:
# (639, 41)

# %%
# Al verificar los nulos, comprobamos que el número ímpar se da por esa razón y subtraímos las filas nulas de las filas totales para saber cuantos duplicados hay.
# el resultado de la suma tiene que ser un número par.
duplicados.shape[0] - duplicados['employeenumber'].isnull().sum()
# Out:
# 208

# %%
# Concluímos que tenemos 208 empleados con el ID de empleado duplicado. 
# Ahora vamos a remover estos nulos de nuestro df de duplicados para poder tratar los duplicados. 
duplicados.dropna(subset='employeenumber', inplace=True)

# %%
# Verificamos como se quedó el df duplicados filtrado
duplicados.head(3)

# %%
# Ahora borramos todos los duplicados que tengan el menor indice, ya que suponemos que los de indice mayor son los registros mas actualizados. 
duplicados.index.name = 'index'  # Agregar nombre al índice
duplicados.head(2)

# %%
# Ordenar el DataFrame por 'employeenumber' y por el índice en orden descendente
df_sorted = duplicados.sort_values(by=['employeenumber', duplicados.index.name], ascending=[True, False])
df_sorted

# %%
# Eliminar duplicados conservando el primer registro encontrado (índice más alto)
df_unique = df_sorted.drop_duplicates(subset='employeenumber', keep='first')
df_unique # nos hemos quedado con 104 filas

# %%
# Restaurar el orden original 
df_unique = df_unique.sort_index()
# Remover el nombre del indice
df_unique.index.name = None

# %%
df_unique['employeenumber'].duplicated().sum()
# Out:
# 0

# %%
df_unique # Este es el df resultante que tiene las filas que queremos mantener en el df completo.
