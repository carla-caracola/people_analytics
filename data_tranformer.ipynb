# %%
# Psssss READ ME! 👋👓
# The purpuse of the following code it to perform transformation of data in order to clean it and make it available for a subsequent analysis
# It will be developed using a class called 'DataTransformer'
# This class will contain different methods which will focus in different data transformation. E.g.:
    # method to delete columns
    # method to standarize columns names (IF NEEDED)
    # method to transform string vaules to lower case
    # method(s) to create new columns
    # method to convert datatype to numeric
    # and any other need detected during the project

# %%
# Imports 📥

# Packages
#-----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Settings
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # to see all columns in DataFrames


# Data 
# -----------------------------------------------------------------------
abc_coorp_df = pd.read_csv("HR RAW DATA.csv", index_col=0)

# %%
abc_coorp_df
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 0                    6          3               NaN              1
# 1                    1          4     Life Sciences              1
# 2                    4          2  Technical Degree              1
# 3                    2          4           Medical              1
# 4                    3          3  Technical Degree              1
# ...                ...        ...               ...            ...
# 1609                 3          1     Life Sciences              1
# 1610                 4          2               NaN              1
# 1611               -13          5               NaN              1
# 1612                 8          4  Technical Degree              1
# 1613                 7          2           Medical              1
#
#      employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 0             162,0                        1       0         51
# 1             259,0                        3       0         65
# 2             319,0                        3       0         58
# 3               NaN                        1       1         82
# 4               NaN                        1       1         45
# ...             ...                      ...     ...        ...
# 1609          967,0                        3       0         51
# 1610          972,0                        3       0         57
# 1611            NaN                       13       0         41
# 1612          990,0                        1       0         84
# 1613            NaN                        4       0         75
#
#       JobInvolvement  JobLevel                   JobRole  JobSatisfaction  \
# 0                  3         5        resEArch DIREcToR                 3
# 1                  2         5                  ManAGeR                 3
# 2                  3         5                  ManaGER                 4
# 3                  3         4        ReseArCH DIrECtOr                 3
# 4                  4         4          sAleS EXECUtIve                 1
# ...              ...       ...                       ...              ...
# 1609               2         3          saLEs ExeCUTiVe                 4
# 1610               3         2    LAboRaTOry tECHNiCIAn                 2
# 1611               4         3          sAlES ExECUTivE                 3
# 1612               3         2          SaLes ExecUtIVe                 4
# 1613               3         3   mAnUfactURInG DiRECTOr                 3
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 0              NaN       19537,0         6462                   7      Y
# 1              NaN       19999,0         5678                   0    NaN
# 2          Married       19232,0         4933                   1    NaN
# 3          Married       17169,0        26703                   3      Y
# 4         Divorced           NaN         7739                   2      Y
# ...            ...           ...          ...                 ...    ...
# 1609       Married       10325,0         5518                   1      Y
# 1610           NaN        4447,0        23163                   1    NaN
# 1611        Single           NaN         2560                   0    NaN
# 1612      Divorced           NaN        25952                   4    NaN
# 1613           NaN       10845,0        24208                   6      Y
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0          No                 13               3,0                         3
# 1         NaN                 14               3,0                         1
# 2          No                 11               3,0                         4
# 3         NaN                 19               3,0                         2
# 4          No                 12               3,0                         4
# ...       ...                ...               ...                       ...
# 1609      NaN                 11               NaN                         1
# 1610      NaN                 12               3,0                         2
# 1611       No                 18               3,0                         4
# 1612       No                 13               NaN                         4
# 1613      NaN                 13               3,0                         2
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 0              NaN                 0               NaN                      5
# 1              NaN                 1              34,0                      5
# 2              NaN                 0              22,0                      3
# 3              NaN                 2               NaN                      2
# 4              NaN                 1               NaN                      5
# ...            ...               ...               ...                    ...
# 1609           NaN                 1               NaN                      6
# 1610           NaN                 0               NaN                      5
# 1611           NaN                 0               9,0                      3
# 1612           NaN                 2              12,0                      3
# 1613           NaN                 1               NaN                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 0                3,0              20                NaN
# 1                3,0              33                NaN
# 2                NaN              22                NaN
# 3                NaN              20                NaN
# 4                3,0              19                NaN
# ...              ...             ...                ...
# 1609             3,0              16                NaN
# 1610             2,0               9                NaN
# 1611             3,0               8                NaN
# 1612             3,0               7                NaN
# 1613             3,0               8                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 0                          15                    15             19537,0
# 1                          11                     9             19999,0
# 2                          11                    15             19232,0
# 3                           5                     6             17169,0
# 4                           2                     8                 NaN
# ...                       ...                   ...                 ...
# 1609                        3                     7             10325,0
# 1610                        0                     8              4447,0
# 1611                        0                     7                 NaN
# 1612                        0                     7                 NaN
# 1613                        0                     7             10845,0
#
#       DateBirth       Salary                       RoleDepartament  \
# 0          1972  1000000000$                                   NaN
# 1          1971  1000000000$                                   NaN
# 2          1981  1000000000$   ManaGER  -  Research & Development
# 3          1976  1000000000$                                   NaN
# 4          1977  1000000000$                                   NaN
# ...         ...          ...                                   ...
# 1609       1987  1000000000$                                   NaN
# 1610       1978  1000000000$                                   NaN
# 1611       1984  1000000000$                                   NaN
# 1612       1987  1000000000$                                   NaN
# 1613       1977  1000000000$                                   NaN
#
#       NUMBERCHILDREN RemoteWork
# 0                NaN        Yes
# 1                NaN          1
# 2                NaN          1
# 3                NaN      False
# 4                NaN          0
# ...              ...        ...
# 1609             NaN          0
# 1610             NaN          1
# 1611             NaN        Yes
# 1612             NaN       True
# 1613             NaN          0
#
# [1614 rows x 41 columns]

# %%
# DataTransformer class definition ✍️

class DataTransformer:
    def __init__(self, dataframe):
        self.df = dataframe

    def replace_gender_values(self):
        """Replaces the values in the Gender column with 'Male' and 'Female'."""
        self.df['Gender'] = self.df['Gender'].replace({0: 'Male', 1: 'Female'})
    
    def convert_age_to_numbers(self):
        """Converts numbers written in text (e.g: 'thirty-two') into numbers ('32'). It does NOT change the data type!"""
        # create a dictionary with numbers written in text as keys and numbers in numbers as values
        conversion_dictionary = {
        "one": 1,
        "two": 2,
        "three": 3,
        "four": 4,
        "five": 5,
        "six": 6,
        "seven": 7,
        "eight": 8,
        "nine": 9,
        "ten": 10,
        "eleven": 11,
        "twelve": 12,
        "thirteen": 13,
        "fourteen": 14,
        "fifteen": 15,
        "sixteen": 16,
        "seventeen": 17,
        "eighteen": 18,
        "nineteen": 19,
        "twenty": 20,
        "twenty-one": 21,
        "twenty-two": 22,
        "twenty-three": 23,
        "twenty-four": 24,
        "twenty-five": 25,
        "twenty-six": 26,
        "twenty-seven": 27,
        "twenty-eight": 28,
        "twenty-nine": 29,
        "thirty": 30,
        "thirty-one": 31,
        "thirty-two": 32,
        "thirty-three": 33,
        "thirty-four": 34,
        "thirty-five": 35,
        "thirty-six": 36,
        "thirty-seven": 37,
        "thirty-eight": 38,
        "thirty-nine": 39,
        "forty": 40,
        "forty-one": 41,
        "forty-two": 42,
        "forty-three": 43,
        "forty-four": 44,
        "forty-five": 45,
        "forty-six": 46,
        "forty-seven": 47,
        "forty-eight": 48,
        "forty-nine": 49,
        "fifty": 50,
        "fifty-one": 51,
        "fifty-two": 52,
        "fifty-three": 53,
        "fifty-four": 54,
        "fifty-five": 55,
        "fifty-six": 56,
        "fifty-seven": 57,
        "fifty-eight": 58,
        "fifty-nine": 59,
        "sixty": 60,
        "sixty-one": 61,
        "sixty-two": 62,
        "sixty-three": 63,
        "sixty-four": 64,
        "sixty-five": 65,
        "sixty-six": 66,
        "sixty-seven": 67,
        "sixty-eight": 68,
        "sixty-nine": 69,
        "seventy": 70,
        "seventy-one": 71,
        "seventy-two": 72,
        "seventy-three": 73,
        "seventy-four": 74,
        "seventy-five": 75,
        "seventy-six": 76,
        "seventy-seven": 77,
        "seventy-eight": 78,
        "seventy-nine": 79,
        "eighty": 80,
        "eighty-one": 81,
        "eighty-two": 82,
        "eighty-three": 83,
        "eighty-four": 84,
        "eighty-five": 85,
        "eighty-six": 86,
        "eighty-seven": 87,
        "eighty-eight": 88,
        "eighty-nine": 89,
        "ninety": 90,
        "ninety-one": 91,
        "ninety-two": 92,
        "ninety-three": 93,
        "ninety-four": 94,
        "ninety-five": 95,
        "ninety-six": 96,
        "ninety-seven": 97,
        "ninety-eight": 98,
        "ninety-nine": 99,
        "one hundred": 100
        }
        for index, value in enumerate(self.df["Age"].values): 
            if value in conversion_dictionary:
                self.df["Age"][index] = conversion_dictionary[value]
                print (f"Value '{value}' was transformed into '{conversion_dictionary[value]}'")







# the following methods were suggeted by chatGPT. REVIEW, EDIT OR DELETE

    def convert_to_numeric(self, column_name):
        """Converts a column to numeric type."""
        self.df[column_name] = pd.to_numeric(self.df[column_name], errors='coerce')

    def remove_duplicates(self):
        """Removes duplicate rows."""
        self.df.drop_duplicates(inplace=True)

    def fix_negative_distances(self):
        """Corrects negative values in the DistanceFromHome column."""
        self.df['DistanceFromHome'] = self.df['DistanceFromHome'].abs()

    def correct_typographical_errors(self):
        """Corrects typographical errors in the MaritalStatus column."""
        self.df['MaritalStatus'] = self.df['MaritalStatus'].replace({'Marreid': 'Married'})

    def drop_redundant_columns(self):
        """Drops redundant columns like 'SameAsMonthlyIncome'."""
        self.df.drop(columns=['SameAsMonthlyIncome'], inplace=True, errors='ignore')

    def get_dataframe(self):
        """Returns the transformed DataFrame."""
        return self.df

# %%
# Instantiating a class object 🐣

abc_data = DataTransformer(abc_coorp_df)

# print for checking

abc_data.df.head(2)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
# 1  52        No            NaN    699,0$        NaN                 1
#
#    Education EducationField  employeecount employeenumber  \
# 0          3            NaN              1          162,0
# 1          4  Life Sciences              1          259,0
#
#    EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1       0         51               3         5
# 1                        3       0         65               2         5
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
#
#   SameAsMonthlyIncome  DateBirth       Salary RoleDepartament  NUMBERCHILDREN  \
# 0             19537,0       1972  1000000000$             NaN             NaN
# 1             19999,0       1971  1000000000$             NaN             NaN
#
#   RemoteWork
# 0        Yes
# 1          1

# %%
abc_data.df["Age"].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 'forty-seven', '53',
#        '43', '60', '32', '37', '49', '39', '50', '44', '30',
#        'fifty-eight', '29', '31', '54', '57', '27', 'thirty-six', '28',
#        '26', 'fifty-five', '25', 'fifty-two', 'thirty-one', '24',
#        'thirty', '23', '22', '21', '20', 'twenty-six', '19',
#        'thirty-seven', '18', 'thirty-two', 'twenty-four'], dtype=object)

# %%
# calling method to convert number written in text into number (column "Age")
abc_data.convert_age_to_numbers()
# Out:
# Value 'forty-seven' was transformed into '47'
# Value 'fifty-eight' was transformed into '58'
# Value 'thirty-six' was transformed into '36'
# Value 'fifty-five' was transformed into '55'
# Value 'fifty-two' was transformed into '52'
# Value 'thirty-one' was transformed into '31'
# Value 'thirty' was transformed into '30'
# Value 'twenty-six' was transformed into '26'
# Value 'thirty-seven' was transformed into '37'
# Value 'thirty-two' was transformed into '32'
# Value 'twenty-four' was transformed into '24'
# Value 'thirty-two' was transformed into '32'
# /tmp/ipykernel_6796/2450857861.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df["Age"][index] = conversion_dictionary[value]

# %%
abc_data.df["Age"].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 47, '53', '43', '60',
#        '32', '37', '49', '39', '50', '44', '30', 58, '29', '31', '54',
#        '57', '27', 36, '28', '26', 55, '25', 52, 31, '24', 30, '23', '22',
#        '21', '20', 26, '19', 37, '18', 32, 24], dtype=object)

# %%
# calling method to replace gender values

abc_data.replace_gender_values()

# %%
# print for checking

abc_data.df.head(2)
# Out:
#   Age Attrition BusinessTravel DailyRate Department  DistanceFromHome  \
# 0  51        No            NaN    684,0$        NaN                 6
# 1  52        No            NaN    699,0$        NaN                 1
#
#    Education EducationField  employeecount employeenumber  \
# 0          3            NaN              1          162,0
# 1          4  Life Sciences              1          259,0
#
#    EnvironmentSatisfaction Gender HourlyRate  JobInvolvement  JobLevel  \
# 0                        1   Male         51               3         5
# 1                        3   Male         65               2         5
#
#                JobRole  JobSatisfaction MaritalStatus MonthlyIncome  \
# 0   resEArch DIREcToR                 3           NaN       19537,0
# 1             ManAGeR                 3           NaN       19999,0
#
#    MonthlyRate  NUMCOMPANIESWORKED Over18 OverTime  PercentSalaryHike  \
# 0         6462                   7      Y       No                 13
# 1         5678                   0    NaN      NaN                 14
#
#   PerformanceRating  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0               3,0                         3           NaN                 0
# 1               3,0                         1           NaN                 1
#
#   TOTALWORKINGYEARS  TrainingTimesLastYear WORKLIFEBALANCE  YearsAtCompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YEARSWITHCURRMANAGER  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
#
#   SameAsMonthlyIncome  DateBirth       Salary RoleDepartament  NUMBERCHILDREN  \
# 0             19537,0       1972  1000000000$             NaN             NaN
# 1             19999,0       1971  1000000000$             NaN             NaN
#
#   RemoteWork
# 0        Yes
# 1          1

# %% [markdown]
# ## Dirty code below ⬇️⬇️

# %%
# method to delete columns
# add a try / except

column_name = "name"

df.drop(column_name, axis = 1, inplace = True)

print(f"Column '{column_name}' was dropped 🗑️\n")

# print df to check if the column was removed succesfully

df.head()

# %%
# method to transform string vaules to lower case

column_name = "name"

# overwrite values within the column with values transformed into lowercase 
df[column_name] = df[column_name].str.lower()

print(f"Values in column '{column_name}' were transformed into lowercase 🔠->🔡\n")

# print df to check if the column values were transformed succesfully
df.head()

# %%
# example: changing to datetime data type

df[column_name] = pd.to_datetime(df[column_name])

# %%
# Method to replace and change lower/upper columns
#  iterate through all the columns of the DataFrame, convert each to lowercase, and apply a replace to remove the dots.
new_columns = {column: column.lower().replace(".", "") for column in df.columns}

# Check that we have created the dictionary correctly
new_columns

# Once we have the dictionary, let's apply the rename method
df.rename(columns = new_columns, inplace = True)

# Check that the column names have been changed
df.head()

# %%
abc_coorp_df
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 0                    6          3               NaN              1
# 1                    1          4     Life Sciences              1
# 2                    4          2  Technical Degree              1
# 3                    2          4           Medical              1
# 4                    3          3  Technical Degree              1
# ...                ...        ...               ...            ...
# 1609                 3          1     Life Sciences              1
# 1610                 4          2               NaN              1
# 1611               -13          5               NaN              1
# 1612                 8          4  Technical Degree              1
# 1613                 7          2           Medical              1
#
#      employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 0             162,0                        1       0         51
# 1             259,0                        3       0         65
# 2             319,0                        3       0         58
# 3               NaN                        1       1         82
# 4               NaN                        1       1         45
# ...             ...                      ...     ...        ...
# 1609          967,0                        3       0         51
# 1610          972,0                        3       0         57
# 1611            NaN                       13       0         41
# 1612          990,0                        1       0         84
# 1613            NaN                        4       0         75
#
#       JobInvolvement  JobLevel                   JobRole  JobSatisfaction  \
# 0                  3         5        resEArch DIREcToR                 3
# 1                  2         5                  ManAGeR                 3
# 2                  3         5                  ManaGER                 4
# 3                  3         4        ReseArCH DIrECtOr                 3
# 4                  4         4          sAleS EXECUtIve                 1
# ...              ...       ...                       ...              ...
# 1609               2         3          saLEs ExeCUTiVe                 4
# 1610               3         2    LAboRaTOry tECHNiCIAn                 2
# 1611               4         3          sAlES ExECUTivE                 3
# 1612               3         2          SaLes ExecUtIVe                 4
# 1613               3         3   mAnUfactURInG DiRECTOr                 3
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 0              NaN       19537,0         6462                   7      Y
# 1              NaN       19999,0         5678                   0    NaN
# 2          Married       19232,0         4933                   1    NaN
# 3          Married       17169,0        26703                   3      Y
# 4         Divorced           NaN         7739                   2      Y
# ...            ...           ...          ...                 ...    ...
# 1609       Married       10325,0         5518                   1      Y
# 1610           NaN        4447,0        23163                   1    NaN
# 1611        Single           NaN         2560                   0    NaN
# 1612      Divorced           NaN        25952                   4    NaN
# 1613           NaN       10845,0        24208                   6      Y
#
#      OverTime  PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0          No                 13               3,0                         3
# 1         NaN                 14               3,0                         1
# 2          No                 11               3,0                         4
# 3         NaN                 19               3,0                         2
# 4          No                 12               3,0                         4
# ...       ...                ...               ...                       ...
# 1609      NaN                 11               NaN                         1
# 1610      NaN                 12               3,0                         2
# 1611       No                 18               3,0                         4
# 1612       No                 13               NaN                         4
# 1613      NaN                 13               3,0                         2
#
#      StandardHours  StockOptionLevel TOTALWORKINGYEARS  TrainingTimesLastYear  \
# 0              NaN                 0               NaN                      5
# 1              NaN                 1              34,0                      5
# 2              NaN                 0              22,0                      3
# 3              NaN                 2               NaN                      2
# 4              NaN                 1               NaN                      5
# ...            ...               ...               ...                    ...
# 1609           NaN                 1               NaN                      6
# 1610           NaN                 0               NaN                      5
# 1611           NaN                 0               9,0                      3
# 1612           NaN                 2              12,0                      3
# 1613           NaN                 1               NaN                      3
#
#      WORKLIFEBALANCE  YearsAtCompany YearsInCurrentRole  \
# 0                3,0              20                NaN
# 1                3,0              33                NaN
# 2                NaN              22                NaN
# 3                NaN              20                NaN
# 4                3,0              19                NaN
# ...              ...             ...                ...
# 1609             3,0              16                NaN
# 1610             2,0               9                NaN
# 1611             3,0               8                NaN
# 1612             3,0               7                NaN
# 1613             3,0               8                NaN
#
#       YearsSinceLastPromotion  YEARSWITHCURRMANAGER SameAsMonthlyIncome  \
# 0                          15                    15             19537,0
# 1                          11                     9             19999,0
# 2                          11                    15             19232,0
# 3                           5                     6             17169,0
# 4                           2                     8                 NaN
# ...                       ...                   ...                 ...
# 1609                        3                     7             10325,0
# 1610                        0                     8              4447,0
# 1611                        0                     7                 NaN
# 1612                        0                     7                 NaN
# 1613                        0                     7             10845,0
#
#       DateBirth       Salary                       RoleDepartament  \
# 0          1972  1000000000$                                   NaN
# 1          1971  1000000000$                                   NaN
# 2          1981  1000000000$   ManaGER  -  Research & Development
# 3          1976  1000000000$                                   NaN
# 4          1977  1000000000$                                   NaN
# ...         ...          ...                                   ...
# 1609       1987  1000000000$                                   NaN
# 1610       1978  1000000000$                                   NaN
# 1611       1984  1000000000$                                   NaN
# 1612       1987  1000000000$                                   NaN
# 1613       1977  1000000000$                                   NaN
#
#       NUMBERCHILDREN RemoteWork
# 0                NaN        Yes
# 1                NaN          1
# 2                NaN          1
# 3                NaN      False
# 4                NaN          0
# ...              ...        ...
# 1609             NaN          0
# 1610             NaN          1
# 1611             NaN        Yes
# 1612             NaN       True
# 1613             NaN          0
#
# [1614 rows x 41 columns]

# %%
abc_coorp_df["Age"].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 'forty-seven', '53',
#        '43', '60', '32', '37', '49', '39', '50', '44', '30',
#        'fifty-eight', '29', '31', '54', '57', '27', 'thirty-six', '28',
#        '26', 'fifty-five', '25', 'fifty-two', 'thirty-one', '24',
#        'thirty', '23', '22', '21', '20', 'twenty-six', '19',
#        'thirty-seven', '18', 'thirty-two', 'twenty-four'], dtype=object)

# %%
"""Converts numbers written in text (e.g: 'thirty-two') into numbers ('32')"""
text_to_number_dict = {
"one": 1,
"two": 2,
"three": 3,
"four": 4,
"five": 5,
"six": 6,
"seven": 7,
"eight": 8,
"nine": 9,
"ten": 10,
"eleven": 11,
"twelve": 12,
"thirteen": 13,
"fourteen": 14,
"fifteen": 15,
"sixteen": 16,
"seventeen": 17,
"eighteen": 18,
"nineteen": 19,
"twenty": 20,
"twenty-one": 21,
"twenty-two": 22,
"twenty-three": 23,
"twenty-four": 24,
"twenty-five": 25,
"twenty-six": 26,
"twenty-seven": 27,
"twenty-eight": 28,
"twenty-nine": 29,
"thirty": 30,
"thirty-one": 31,
"thirty-two": 32,
"thirty-three": 33,
"thirty-four": 34,
"thirty-five": 35,
"thirty-six": 36,
"thirty-seven": 37,
"thirty-eight": 38,
"thirty-nine": 39,
"forty": 40,
"forty-one": 41,
"forty-two": 42,
"forty-three": 43,
"forty-four": 44,
"forty-five": 45,
"forty-six": 46,
"forty-seven": 47,
"forty-eight": 48,
"forty-nine": 49,
"fifty": 50,
"fifty-one": 51,
"fifty-two": 52,
"fifty-three": 53,
"fifty-four": 54,
"fifty-five": 55,
"fifty-six": 56,
"fifty-seven": 57,
"fifty-eight": 58,
"fifty-nine": 59,
"sixty": 60,
"sixty-one": 61,
"sixty-two": 62,
"sixty-three": 63,
"sixty-four": 64,
"sixty-five": 65,
"sixty-six": 66,
"sixty-seven": 67,
"sixty-eight": 68,
"sixty-nine": 69,
"seventy": 70,
"seventy-one": 71,
"seventy-two": 72,
"seventy-three": 73,
"seventy-four": 74,
"seventy-five": 75,
"seventy-six": 76,
"seventy-seven": 77,
"seventy-eight": 78,
"seventy-nine": 79,
"eighty": 80,
"eighty-one": 81,
"eighty-two": 82,
"eighty-three": 83,
"eighty-four": 84,
"eighty-five": 85,
"eighty-six": 86,
"eighty-seven": 87,
"eighty-eight": 88,
"eighty-nine": 89,
"ninety": 90,
"ninety-one": 91,
"ninety-two": 92,
"ninety-three": 93,
"ninety-four": 94,
"ninety-five": 95,
"ninety-six": 96,
"ninety-seven": 97,
"ninety-eight": 98,
"ninety-nine": 99,
"one hundred": 100
}

for index, value in enumerate(abc_coorp_df["Age"].values): 
    if value in text_to_number_dict:
        abc_coorp_df["Age"][index] = text_to_number_dict[value]
        print (f"El valor: {value} se transformó a {text_to_number_dict[value]}")
# Out:
# El valor: forty-seven se transformó a 47
# El valor: fifty-eight se transformó a 58
# El valor: thirty-six se transformó a 36
# El valor: fifty-five se transformó a 55
# El valor: fifty-two se transformó a 52
# El valor: thirty-one se transformó a 31
# El valor: thirty se transformó a 30
# El valor: twenty-six se transformó a 26
# El valor: thirty-seven se transformó a 37
# El valor: thirty-two se transformó a 32
# El valor: twenty-four se transformó a 24
# El valor: thirty-two se transformó a 32
# /tmp/ipykernel_6796/4096119043.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abc_coorp_df["Age"][index] = text_to_number_dict[value]

# %%
abc_coorp_df["Age"].unique()
# Out:
# array(['51', '52', '42', '47', '46', '48', '59', '41', '56', '38', '55',
#        '40', '58', '35', '45', '33', '36', '34', 47, '53', '43', '60',
#        '32', '37', '49', '39', '50', '44', '30', 58, '29', '31', '54',
#        '57', '27', 36, '28', '26', 55, '25', 52, 31, '24', 30, '23', '22',
#        '21', '20', 26, '19', 37, '18', 32, 24], dtype=object)
